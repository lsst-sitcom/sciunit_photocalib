# %% [markdown]
# # ABoffsets_LSSTComCam_c26202
#
# Authors:  C. L. Adair, D. L. Tucker, with help from L. Jones, J. Carlin, and others
#
# Created:  2024.11.15
# Updated: 2025.01.29 (and it has cool stuff in here...I'm impressed with us)

# %% [markdown]
# ## 1. Initial Setup...

# %%
# %pwd
# Out:
# '/home/c/cadair/WORK/Douglas_stuff'

# %% [markdown]
# ### 1.1 Import useful python packages

# %%
# Generic python packages
import pylab as plt
import numpy as np
import pandas as pd
import glob
import math
import os
import gc
import warnings

# LSST Science Pipelines (Stack) packages
import lsst.daf.butler as dafButler
import lsst.afw.display as afwDisplay

# rubin_sim-related packages
import rubin_sim.phot_utils as pt
import syseng_throughputs as st
from rubin_sim.data import get_data_dir

# Astropy-related packages
from astropy import units as u
from astropy.io import fits
from astropy.coordinates import SkyCoord
import lsst.geom as geom

# Set a standard figure size to use
plt.rcParams['figure.figsize'] = (8.0, 8.0)
afwDisplay.setDefaultBackend('matplotlib')

# Set filter warnings to "ignore" to avoid a lot of "logorrhea" to the screen:
warnings.filterwarnings("ignore")
# Out:
# /home/c/cadair/WORK/GitHub/syseng_throughputs/syseng_throughputs/bandpassUtils.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ### 1.2 Include user input

# %%
# Which repo, collection, instrument, and skymap to use.
# See https://rubinobs.atlassian.net/wiki/spaces/DM/pages/48834013/Campaigns#1.1.-ComCam
# and https://rubinobs.atlassian.net/wiki/spaces/DM/pages/226656354/LSSTComCam+Intermittent+Cumulative+DRP+Runs
#repo = 'embargo'
#repo = '/repo/dp1'
repo = '/repo/main'
#collections = 'LSSTComCam/runs/DRP/DP1/v29_0_0/DM-50260'
collections = 'LSSTCam/runs/DRP/20250604_20250921/w_2025_39/DM-52645'

#instrument = 'LSSTComCam'
instrument = 'LSSTCam'
skymap_name = 'lsst_cells_v1'
#day_obs_start = 20241101
#day_obs_end = 20241231
day_obs_start = 20250401
day_obs_end = 20251230
plotImages = False
plotCutouts = False

# Set environment variable to point to location of the rubin_sim_data 
#  (per Lynne Jones' Slack message on the #sciunit-photo-calib channel from 26 Nov 2024):
os.environ["RUBIN_SIM_DATA_DIR"] = "/sdf/data/rubin/shared/rubin_sim_data"

# Which CalSpec C26202 spectrum FITS files to to use?
sedfile_dict = {'stiswfcnic_007' : '~/Downloads/c26202_stiswfcnic_007.fits', 
                'mod_008'        : '~/Downloads/c26202_mod_008.fits'
               }

# RA, DEC of C26202 in degrees (from `/home/d/dltucker/DATA/SynthMags/synthMagColorList.lsst_v1.9.calspec_20240603.added_info.csv`):
raDeg = 53.136845833333325
decDeg = -27.86349444444444

# List of filters to examine
flist = ['u','g','r','i','z','y']

# Plot symbol colors to use for ugrizy
plot_filter_colors_white_background = {'u': '#0c71ff', 'g': '#49be61', 'r': '#c61c00', 'i': '#ffc200', 'z': '#f341a2', 'y': '#5d0000'}

# %% [markdown]
# ### 1.3 Define useful classes and functions

# %%
# Useful class to stop "Run All" at a cell 
#  containing the command "raise StopExecution"
class StopExecution(Exception):
    def _render_traceback_(self):
        pass

# %%
def cutout_im(butler, ra, dec, datasetType, visit, detector, cutoutSideLength=51, **kwargs):
    
    """
    Produce a cutout from a preliminary_visit_image at the given ra, dec position.

    Adapted from cutout_coadd which was adapted from a DC2 tutorial
    notebook by Michael Wood-Vasey.

    """
    
    dataId = {'visit': visit, 'detector': detector}    
    radec = geom.SpherePoint(ra, dec, geom.degrees)
    cutoutSize = geom.ExtentI(cutoutSideLength, cutoutSideLength)
    wcs = butler.get('%s.wcs' % datasetType,**dataId)
    xy = geom.PointI(wcs.skyToPixel(radec))
    bbox = geom.BoxI(xy - cutoutSize // 2, cutoutSize)
    parameters = {'bbox': bbox}
    cutout_image = butler.get(datasetType, parameters=parameters, **dataId)

    return cutout_image

# %%
def warp_img(ref_img, img_to_warp, ref_wcs, wcs_to_warp):

    config = RegisterConfig()
    task = RegisterTask(name="register", config=config)
    warpedExp = task.warpExposure(img_to_warp, wcs_to_warp, ref_wcs,
                                  ref_img.getBBox())

    return warpedExp

# %%
def make_gif(frame_folder):
    frames = [Image.open(image) for image in sorted(glob.glob(f"{frame_folder}/*.png"))]
    frame_one = frames[0]
    frame_one.save("animation.gif", format="GIF", append_images=frames,
               save_all=True, duration=500, loop = 0)

# %% [markdown]
# ## 2. Calculate Synthetic AB magnitudes for C26202, based on official filter bandpasses

# %% [markdown]
# ### 2.1 Change detectors from (default) LSST to ComCam

# %%
defaultDirs = st.setDefaultDirs()
defaultDirs['detector'] = defaultDirs['detector'].replace('/joint_minimum', '/itl')
hardware, system = st.buildHardwareAndSystem(defaultDirs)

# %% [markdown]
# ### 2.2 Calculate synthetic mags

# %%
mags = {}

# Loop through all SEDs in our sedfile dictionary
for sed_key in sedfile_dict:
    
    print(sed_key, sedfile_dict[sed_key])
    
    # Read the SED file associated with this SED
    sedfile = sedfile_dict[sed_key]
    seddata = fits.getdata(sedfile)

    # Transform the SED data into rubin_sim format
    wavelen = seddata['WAVELENGTH'] * u.angstrom.to(u.nanometer) # This is in angstroms - need in nanometers
    flambda = seddata['FLUX'] / (u.angstrom.to(u.nanometer)) # this is in erg/sec/cm^^2/ang but we want /nm     
    sed = pt.Sed(wavelen=wavelen, flambda=flambda)
    
    # Loop over the filters, calculating the synthetic mags for each filter for this SED
    mags[sed_key] = []
    for f in flist:
        # Append the synthetic mag for this filter to this mags list for this SED
        mags[sed_key].append(sed.calc_mag(system[f]))
    # Convert list of synthetic mags for this SED into a numpy array
    mags[sed_key] = np.array(mags[sed_key])
# Out:
# stiswfcnic_007 ~/Downloads/c26202_stiswfcnic_007.fits
# mod_008 ~/Downloads/c26202_mod_008.fits

# %% [markdown]
# ### 2.3 Convert mags numpy arrays into a pandas dataframe

# %%
df_mags = pd.DataFrame(mags, index=flist)
df_mags
# Out:
#    stiswfcnic_007    mod_008
# u       17.572800  17.586964
# g       16.691931  16.692687
# r       16.362017  16.361654
# i       16.260196  16.259542
# z       16.243679  16.243690
# y       16.238847  16.238887

# %% [markdown]
# ## 3. Query USDF Butler for ComCam measurements of C26202

# %% [markdown]
# ### 3.1 Instantiate Butler

# %%
butler = dafButler.Butler(repo, collections=collections)

# %% [markdown]
# ### 3.2 Find all the `preliminary_visit_image`'s that overlap the sky position of C26202

# %% [markdown]
# #### 3.2.1 Find the `dataId`'s for all `preliminary_visit_image`'s in this repo/collection that overlap the RA, DEC of C26202

# %%
datasetRefs = butler.query_datasets("visit_image", where="visit_detector_region.region OVERLAPS POINT(ra, dec)",
                                    bind={"ra": raDeg, "dec": decDeg})

for i, ref in enumerate(datasetRefs):    
    print(i, ref.dataId)

print(f"\nFound {len(datasetRefs)} preliminary_visit_images")
# Out:
# 0 {instrument: 'LSSTCam', detector: 44, visit: 2025090600260, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 1 {instrument: 'LSSTCam', detector: 49, visit: 2025090600252, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 2 {instrument: 'LSSTCam', detector: 51, visit: 2025090600256, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 3 {instrument: 'LSSTCam', detector: 51, visit: 2025090600266, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 4 {instrument: 'LSSTCam', detector: 51, visit: 2025090600280, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 5 {instrument: 'LSSTCam', detector: 52, visit: 2025082600442, band: 'i', day_obs: 20250826, physical_filter: 'i_39'}
# 6 {instrument: 'LSSTCam', detector: 52, visit: 2025082600445, band: 'i', day_obs: 20250826, physical_filter: 'i_39'}
# 7 {instrument: 'LSSTCam', detector: 52, visit: 2025090600254, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 8 {instrument: 'LSSTCam', detector: 52, visit: 2025090600259, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 9 {instrument: 'LSSTCam', detector: 53, visit: 2025090600253, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 10 {instrument: 'LSSTCam', detector: 53, visit: 2025090600270, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 11 {instrument: 'LSSTCam', detector: 53, visit: 2025090600285, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 12 {instrument: 'LSSTCam', detector: 60, visit: 2025090600277, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 13 {instrument: 'LSSTCam', detector: 61, visit: 2025090600274, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 14 {instrument: 'LSSTCam', detector: 61, visit: 2025090600278, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 15 {instrument: 'LSSTCam', detector: 86, visit: 2025090600262, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 16 {instrument: 'LSSTCam', detector: 90, visit: 2025081000328, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 17 {instrument: 'LSSTCam', detector: 90, visit: 2025081000329, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 18 {instrument: 'LSSTCam', detector: 90, visit: 2025081000330, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 19 {instrument: 'LSSTCam', detector: 90, visit: 2025081000331, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 20 {instrument: 'LSSTCam', detector: 90, visit: 2025081000332, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 21 {instrument: 'LSSTCam', detector: 90, visit: 2025081000333, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 22 {instrument: 'LSSTCam', detector: 90, visit: 2025081300332, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 23 {instrument: 'LSSTCam', detector: 90, visit: 2025090600255, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 24 {instrument: 'LSSTCam', detector: 90, visit: 2025090600258, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 25 {instrument: 'LSSTCam', detector: 90, visit: 2025090600264, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 26 {instrument: 'LSSTCam', detector: 90, visit: 2025090600269, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 27 {instrument: 'LSSTCam', detector: 90, visit: 2025090600279, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 28 {instrument: 'LSSTCam', detector: 90, visit: 2025090600280, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
#
# 90 {instrument: 'LSSTCam', detector: 95, visit: 2025072100530, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 91 {instrument: 'LSSTCam', detector: 95, visit: 2025072100531, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 92 {instrument: 'LSSTCam', detector: 95, visit: 2025072100532, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 93 {instrument: 'LSSTCam', detector: 95, visit: 2025072100533, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 94 {instrument: 'LSSTCam', detector: 95, visit: 2025072100534, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 95 {instrument: 'LSSTCam', detector: 95, visit: 2025072100535, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 96 {instrument: 'LSSTCam', detector: 95, visit: 2025072200465, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 97 {instrument: 'LSSTCam', detector: 95, visit: 2025072200466, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 98 {instrument: 'LSSTCam', detector: 95, visit: 2025072200467, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 99 {instrument: 'LSSTCam', detector: 95, visit: 2025072200468, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 100 {instrument: 'LSSTCam', detector: 95, visit: 2025072200469, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 101 {instrument: 'LSSTCam', detector: 95, visit: 2025072200470, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 102 {instrument: 'LSSTCam', detector: 95, visit: 2025072200474, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 103 {instrument: 'LSSTCam', detector: 95, visit: 2025072200478, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 104 {instrument: 'LSSTCam', detector: 95, visit: 2025072200479, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 105 {instrument: 'LSSTCam', detector: 95, visit: 2025072200480, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 106 {instrument: 'LSSTCam', detector: 95, visit: 2025072200481, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 107 {instrument: 'LSSTCam', detector: 95, visit: 2025072200482, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 108 {instrument: 'LSSTCam', detector: 95, visit: 2025072300437, band: 'g', day_obs: 20250723, physical_filter: 'g_6'}
# 109 {instrument: 'LSSTCam', detector: 95, visit: 2025072300438, band: 'g', day_obs: 20250723, physical_filter: 'g_6'}
# 110 {instrument: 'LSSTCam', detector: 95, visit: 2025072300445, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 111 {instrument: 'LSSTCam', detector: 95, visit: 2025072300446, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 112 {instrument: 'LSSTCam', detector: 95, visit: 2025072300447, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 113 {instrument: 'LSSTCam', detector: 95, visit: 2025072300448, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 147 {instrument: 'LSSTCam', detector: 99, visit: 2025071100820, band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 148 {instrument: 'LSSTCam', detector: 99, visit: 2025081300308, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 149 {instrument: 'LSSTCam', detector: 99, visit: 2025090600282, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 150 {instrument: 'LSSTCam', detector: 100, visit: 2025090600274, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 151 {instrument: 'LSSTCam', detector: 102, visit: 2025081300309, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 152 {instrument: 'LSSTCam', detector: 102, visit: 2025081300337, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 153 {instrument: 'LSSTCam', detector: 102, visit: 2025082600426, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
# 154 {instrument: 'LSSTCam', detector: 102, visit: 2025082600427, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
# 155 {instrument: 'LSSTCam', detector: 102, visit: 2025082600428, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
# 156 {instrument: 'LSSTCam', detector: 102, visit: 2025082600429, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
#
# Found 157 preliminary_visit_images

# %% [markdown]
# #### 3.2.2 Plot the cutouts for all these `preliminary_visit_image`'s

# %% [markdown]
# **Tina, could use add some code here from the DP02_04b_Intermediate_Butler_Queries tutorial notebook so we can view these `preliminary_visit_image` images?  Maybe something from Section 3.1 from that tutorial notebook.  It would be good to take a look at the individual images in case there are any weird `preliminary_visit_image` images that we should ignore.**

# %%
preliminary_visit_image = butler.get('visit_image', dataId={'visit': 2025082600428, 'detector': 102})

# %%
preliminary_visit_image_info = preliminary_visit_image.getInfo()

# %%
visit_info = preliminary_visit_image_info.getVisitInfo()
summary_info = preliminary_visit_image_info.getSummaryStats()

# %%
summary_info
# Out:
# ExposureSummaryStats(version=0, psfSigma=3.473914345515934, psfArea=175.45994162851082, psfIxx=11.071289733384054, psfIyy=13.263372958000371, psfIxy=1.09730065806075, ra=53.13215720227235, dec=-27.865368530501417, pixelScale=0.20012844925156828, zenithDistance=42.23763368329869, expTime=30.0011570453644, zeroPoint=32.19012058973447, skyBg=423.7015686035156, skyNoise=20.98273101950677, meanVar=442.7829082613866, raCorners=[52.9636644781996, 53.0721401764232, 53.30045975953352, 53.19229067185726], decCorners=[-27.921709712954282, -27.71535199127778, -27.808823711395693, -28.015450828724127], astromOffsetMean=nan, astromOffsetStd=nan, nPsfStar=37, psfStarDeltaE1Median=-0.0016093328595160605, psfStarDeltaE2Median=0.003593947738408987, psfStarDeltaE1Scatter=0.013530752700481648, psfStarDeltaE2Scatter=0.01556384213574282, psfStarDeltaSizeMedian=0.010976332041586545, psfStarDeltaSizeScatter=0.037581139860330424, psfStarScaledDeltaSizeScatter=0.010740699026622556, psfTraceRadiusDelta=0.11220198177219176, psfApFluxDelta=0.011703071895610262, psfApCorrSigmaScaledDelta=0.007948830779776013, maxDistToNearestPsf=1362.2438116373116, effTime=7.05832871936674, effTimePsfSigmaScale=0.2201592802056274, effTimeSkyBgScale=1.0939725285384132, effTimeZeroPointScale=0.9768333155683716, magLim=24.31267352738327)

# %%
datasetType = 'visit_image'
dataId = {'visit': 2025082600428, 'detector': 102}
preliminary_visit_image = butler.get(datasetType, dataId=dataId)

# %%
print(butler.registry.getDatasetType(datasetType))
# Out:
# DatasetType('visit_image', {band, instrument, day_obs, detector, physical_filter, visit}, ExposureF)

# %%
if plotCutouts:
    fig = plt.figure()
    display = afwDisplay.Display(frame=fig)
    display.scale('asinh', 'zscale')
    display.mtv(preliminary_visit_image.image)
    plt.show()

# %%
cutoutsize = 501 #Defining the size of the cutout box in pixels
visit = 2025082600428
detector = 102

# %%
cutout_preliminary_visit_image = cutout_im(butler, raDeg, decDeg, 'visit_image', visit, detector, cutoutSideLength=cutoutsize)

# %%
if plotCutouts:
    fig = plt.figure()
    display = afwDisplay.Display(frame=fig)
    display.scale('asinh', 'zscale')
    display.mtv(cutout_preliminary_visit_image.image)
    plt.show()

# %% [markdown]
# #### 3.2.3 Create a pandas Dataframe containing the `sourceTable` info for all these `preliminary_visit_image`'s

# %% [markdown]
# Now, loop over the `datasetRefs` again, but this time grab the contents of the `sourceTable` table for each `ref` and combine into all into one big pandas DataFrame.

# %%
src_list = []

for i, ref in enumerate(datasetRefs):
    
    # Retrieve sourceTable for this visit & detector...
    dataId = {'visit': ref.dataId['visit'], 'detector': ref.dataId['detector']}
    src = butler.get('recalibrated_star_detector', dataId=dataId)
    src_list.append(src.to_pandas())
    print(f"{i} Visit {ref.dataId['visit']}, Detector {ref.dataId['detector']}:  Retrieved catalog of {len(src)} sources.")

src_all = pd.concat(src_list, ignore_index=True)

print("")
print(f"Total combined catalog contains {len(src_all)} sources.")
# Out:
# 0 Visit 2025090600260, Detector 44:  Retrieved catalog of 953 sources.
# 1 Visit 2025090600252, Detector 49:  Retrieved catalog of 587 sources.
# 2 Visit 2025090600256, Detector 51:  Retrieved catalog of 943 sources.
# 3 Visit 2025090600266, Detector 51:  Retrieved catalog of 1093 sources.
# 4 Visit 2025090600280, Detector 51:  Retrieved catalog of 499 sources.
# 5 Visit 2025082600442, Detector 52:  Retrieved catalog of 2478 sources.
# 6 Visit 2025082600445, Detector 52:  Retrieved catalog of 2514 sources.
# 7 Visit 2025090600254, Detector 52:  Retrieved catalog of 913 sources.
# 8 Visit 2025090600259, Detector 52:  Retrieved catalog of 889 sources.
# 9 Visit 2025090600253, Detector 53:  Retrieved catalog of 727 sources.
# 10 Visit 2025090600270, Detector 53:  Retrieved catalog of 1119 sources.
# 11 Visit 2025090600285, Detector 53:  Retrieved catalog of 733 sources.
# 12 Visit 2025090600277, Detector 60:  Retrieved catalog of 636 sources.
# 13 Visit 2025090600274, Detector 61:  Retrieved catalog of 674 sources.
# 14 Visit 2025090600278, Detector 61:  Retrieved catalog of 611 sources.
# 15 Visit 2025090600262, Detector 86:  Retrieved catalog of 955 sources.
# 16 Visit 2025081000328, Detector 90:  Retrieved catalog of 1020 sources.
# 17 Visit 2025081000329, Detector 90:  Retrieved catalog of 939 sources.
# 18 Visit 2025081000330, Detector 90:  Retrieved catalog of 941 sources.
# 19 Visit 2025081000331, Detector 90:  Retrieved catalog of 1062 sources.
# 20 Visit 2025081000332, Detector 90:  Retrieved catalog of 1150 sources.
# 21 Visit 2025081000333, Detector 90:  Retrieved catalog of 1239 sources.
# 22 Visit 2025081300332, Detector 90:  Retrieved catalog of 2047 sources.
# 23 Visit 2025090600255, Detector 90:  Retrieved catalog of 744 sources.
# 24 Visit 2025090600258, Detector 90:  Retrieved catalog of 1024 sources.
# 25 Visit 2025090600264, Detector 90:  Retrieved catalog of 1009 sources.
# 26 Visit 2025090600269, Detector 90:  Retrieved catalog of 980 sources.
# 27 Visit 2025090600279, Detector 90:  Retrieved catalog of 591 sources.
# 28 Visit 2025090600280, Detector 90:  Retrieved catalog of 656 sources.
# 29 Visit 2025082600441, Detector 91:  Retrieved catalog of 2095 sources.
# 30 Visit 2025082600443, Detector 91:  Retrieved catalog of 2313 sources.
# 31 Visit 2025082600444, Detector 91:  Retrieved catalog of 2188 sources.
# 32 Visit 2025082600446, Detector 91:  Retrieved catalog of 2640 sources.
# 33 Visit 2025090600263, Detector 91:  Retrieved catalog of 988 sources.
# 34 Visit 2025090600272, Detector 91:  Retrieved catalog of 606 sources.
# 35 Visit 2025090600279, Detector 91:  Retrieved catalog of 616 sources.
# 36 Visit 2025090600284, Detector 91:  Retrieved catalog of 729 sources.
# 37 Visit 2025071100809, Detector 92:  Retrieved catalog of 254 sources.
# 38 Visit 2025071100810, Detector 92:  Retrieved catalog of 234 sources.
# 39 Visit 2025071100811, Detector 92:  Retrieved catalog of 278 sources.
# 40 Visit 2025071100812, Detector 92:  Retrieved catalog of 187 sources.
# 41 Visit 2025071100819, Detector 92:  Retrieved catalog of 313 sources.
# 42 Visit 2025071100820, Detector 92:  Retrieved catalog of 520 sources.
# 43 Visit 2025071200713, Detector 92:  Retrieved catalog of 645 sources.
# 44 Visit 2025071200714, Detector 92:  Retrieved catalog of 753 sources.
# 45 Visit 2025071200735, Detector 92:  Retrieved catalog of 1214 sources.
# 46 Visit 2025071200736, Detector 92:  Retrieved catalog of 1192 sources.
# 47 Visit 2025071200737, Detector 92:  Retrieved catalog of 1251 sources.
# 48 Visit 2025071200738, Detector 92:  Retrieved catalog of 1128 sources.
# 49 Visit 2025071200739, Detector 92:  Retrieved catalog of 1231 sources.
# 50 Visit 2025081300306, Detector 92:  Retrieved catalog of 1868 sources.
# 51 Visit 2025081300310, Detector 92:  Retrieved catalog of 1739 sources.
# 52 Visit 2025081300334, Detector 92:  Retrieved catalog of 2246 sources.
# 53 Visit 2025081300336, Detector 92:  Retrieved catalog of 2258 sources.
# 54 Visit 2025090600265, Detector 92:  Retrieved catalog of 989 sources.
# 55 Visit 2025090600257, Detector 93:  Retrieved catalog of 932 sources.
# 56 Visit 2025090600267, Detector 93:  Retrieved catalog of 1028 sources.
# 57 Visit 2025090600273, Detector 93:  Retrieved catalog of 695 sources.
# 58 Visit 2025081300333, Detector 94:  Retrieved catalog of 2235 sources.
# 59 Visit 2025090600261, Detector 94:  Retrieved catalog of 857 sources.
# 60 Visit 2025090600268, Detector 94:  Retrieved catalog of 984 sources.
# 61 Visit 2025090600271, Detector 94:  Retrieved catalog of 641 sources.
# 62 Visit 2025090600276, Detector 94:  Retrieved catalog of 682 sources.
# 63 Visit 2025071700593, Detector 95:  Retrieved catalog of 677 sources.
# 64 Visit 2025071700594, Detector 95:  Retrieved catalog of 653 sources.
# 65 Visit 2025071700595, Detector 95:  Retrieved catalog of 734 sources.
# 66 Visit 2025071700602, Detector 95:  Retrieved catalog of 1872 sources.
# 67 Visit 2025071700603, Detector 95:  Retrieved catalog of 2011 sources.
# 68 Visit 2025071700604, Detector 95:  Retrieved catalog of 1936 sources.
# 69 Visit 2025071700605, Detector 95:  Retrieved catalog of 1898 sources.
# 70 Visit 2025071700606, Detector 95:  Retrieved catalog of 2002 sources.
# 71 Visit 2025071700607, Detector 95:  Retrieved catalog of 1981 sources.
# 72 Visit 2025071900574, Detector 95:  Retrieved catalog of 1645 sources.
# 73 Visit 2025071900575, Detector 95:  Retrieved catalog of 1338 sources.
# 74 Visit 2025071900576, Detector 95:  Retrieved catalog of 1306 sources.
# 75 Visit 2025071900577, Detector 95:  Retrieved catalog of 1294 sources.
# 76 Visit 2025071900578, Detector 95:  Retrieved catalog of 1409 sources.
# 77 Visit 2025071900579, Detector 95:  Retrieved catalog of 1334 sources.
# 78 Visit 2025071900580, Detector 95:  Retrieved catalog of 1239 sources.
# 79 Visit 2025071900586, Detector 95:  Retrieved catalog of 1899 sources.
# 80 Visit 2025071900587, Detector 95:  Retrieved catalog of 1790 sources.
# 81 Visit 2025071900588, Detector 95:  Retrieved catalog of 1809 sources.
# 82 Visit 2025071900589, Detector 95:  Retrieved catalog of 1780 sources.
# 83 Visit 2025071900590, Detector 95:  Retrieved catalog of 1861 sources.
# 84 Visit 2025072100524, Detector 95:  Retrieved catalog of 1203 sources.
# 85 Visit 2025072100525, Detector 95:  Retrieved catalog of 1195 sources.
# 86 Visit 2025072100526, Detector 95:  Retrieved catalog of 1223 sources.
# 87 Visit 2025072100527, Detector 95:  Retrieved catalog of 1403 sources.
# 88 Visit 2025072100528, Detector 95:  Retrieved catalog of 1490 sources.
# 89 Visit 2025072100529, Detector 95:  Retrieved catalog of 1474 sources.
# 90 Visit 2025072100530, Detector 95:  Retrieved catalog of 2249 sources.
# 91 Visit 2025072100531, Detector 95:  Retrieved catalog of 2096 sources.
# 92 Visit 2025072100532, Detector 95:  Retrieved catalog of 1968 sources.
# 93 Visit 2025072100533, Detector 95:  Retrieved catalog of 2029 sources.
# 94 Visit 2025072100534, Detector 95:  Retrieved catalog of 2086 sources.
# 95 Visit 2025072100535, Detector 95:  Retrieved catalog of 2103 sources.
# 96 Visit 2025072200465, Detector 95:  Retrieved catalog of 513 sources.
# 97 Visit 2025072200466, Detector 95:  Retrieved catalog of 438 sources.
# 98 Visit 2025072200467, Detector 95:  Retrieved catalog of 444 sources.
# 99 Visit 2025072200468, Detector 95:  Retrieved catalog of 614 sources.
# 100 Visit 2025072200469, Detector 95:  Retrieved catalog of 506 sources.
# 101 Visit 2025072200470, Detector 95:  Retrieved catalog of 743 sources.
# 102 Visit 2025072200474, Detector 95:  Retrieved catalog of 825 sources.
# 103 Visit 2025072200478, Detector 95:  Retrieved catalog of 1123 sources.
# 104 Visit 2025072200479, Detector 95:  Retrieved catalog of 915 sources.
# 105 Visit 2025072200480, Detector 95:  Retrieved catalog of 964 sources.
# 106 Visit 2025072200481, Detector 95:  Retrieved catalog of 982 sources.
# 107 Visit 2025072200482, Detector 95:  Retrieved catalog of 1103 sources.
# 108 Visit 2025072300437, Detector 95:  Retrieved catalog of 400 sources.
# 109 Visit 2025072300438, Detector 95:  Retrieved catalog of 424 sources.
# 110 Visit 2025072300445, Detector 95:  Retrieved catalog of 1311 sources.
# 111 Visit 2025072300446, Detector 95:  Retrieved catalog of 1308 sources.
# 112 Visit 2025072300447, Detector 95:  Retrieved catalog of 1353 sources.
# 113 Visit 2025072300448, Detector 95:  Retrieved catalog of 955 sources.
# 114 Visit 2025072300449, Detector 95:  Retrieved catalog of 1063 sources.
# 115 Visit 2025072300450, Detector 95:  Retrieved catalog of 1361 sources.
# 116 Visit 2025072800366, Detector 95:  Retrieved catalog of 1457 sources.
# 117 Visit 2025072800368, Detector 95:  Retrieved catalog of 1244 sources.
# 118 Visit 2025072800369, Detector 95:  Retrieved catalog of 1313 sources.
# 119 Visit 2025072800370, Detector 95:  Retrieved catalog of 1475 sources.
# 120 Visit 2025072800371, Detector 95:  Retrieved catalog of 1501 sources.
# 121 Visit 2025072800396, Detector 95:  Retrieved catalog of 2496 sources.
# 122 Visit 2025072800397, Detector 95:  Retrieved catalog of 2343 sources.
# 123 Visit 2025072800398, Detector 95:  Retrieved catalog of 2386 sources.
# 124 Visit 2025072800399, Detector 95:  Retrieved catalog of 2518 sources.
# 125 Visit 2025072800400, Detector 95:  Retrieved catalog of 2689 sources.
# 126 Visit 2025072800401, Detector 95:  Retrieved catalog of 2741 sources.
# 127 Visit 2025081300305, Detector 95:  Retrieved catalog of 1907 sources.
# 128 Visit 2025081300307, Detector 95:  Retrieved catalog of 1626 sources.
# 129 Visit 2025081300309, Detector 95:  Retrieved catalog of 1754 sources.
# 130 Visit 2025081300333, Detector 95:  Retrieved catalog of 2100 sources.
# 131 Visit 2025081300335, Detector 95:  Retrieved catalog of 2167 sources.
# 132 Visit 2025081300337, Detector 95:  Retrieved catalog of 2187 sources.
# 133 Visit 2025082600425, Detector 95:  Retrieved catalog of 1899 sources.
# 134 Visit 2025082600430, Detector 95:  Retrieved catalog of 1969 sources.
# 135 Visit 2025090600275, Detector 98:  Retrieved catalog of 610 sources.
# 136 Visit 2025090600281, Detector 98:  Retrieved catalog of 682 sources.
# 137 Visit 2025090600283, Detector 98:  Retrieved catalog of 673 sources.
# 138 Visit 2025071100809, Detector 99:  Retrieved catalog of 352 sources.
# 139 Visit 2025071100810, Detector 99:  Retrieved catalog of 354 sources.
# 140 Visit 2025071100811, Detector 99:  Retrieved catalog of 364 sources.
# 141 Visit 2025071100812, Detector 99:  Retrieved catalog of 355 sources.
# 142 Visit 2025071100814, Detector 99:  Retrieved catalog of 312 sources.
# 143 Visit 2025071100816, Detector 99:  Retrieved catalog of 474 sources.
# 144 Visit 2025071100817, Detector 99:  Retrieved catalog of 590 sources.
# 145 Visit 2025071100818, Detector 99:  Retrieved catalog of 714 sources.
# 146 Visit 2025071100819, Detector 99:  Retrieved catalog of 869 sources.
# 147 Visit 2025071100820, Detector 99:  Retrieved catalog of 839 sources.
# 148 Visit 2025081300308, Detector 99:  Retrieved catalog of 1824 sources.
# 149 Visit 2025090600282, Detector 99:  Retrieved catalog of 597 sources.
# 150 Visit 2025090600274, Detector 100:  Retrieved catalog of 685 sources.
# 151 Visit 2025081300309, Detector 102:  Retrieved catalog of 1797 sources.
# 152 Visit 2025081300337, Detector 102:  Retrieved catalog of 2207 sources.
# 153 Visit 2025082600426, Detector 102:  Retrieved catalog of 1772 sources.
# 154 Visit 2025082600427, Detector 102:  Retrieved catalog of 1764 sources.
# 155 Visit 2025082600428, Detector 102:  Retrieved catalog of 1810 sources.
# 156 Visit 2025082600429, Detector 102:  Retrieved catalog of 1523 sources.
#
# Total combined catalog contains 197526 sources.

# %% [markdown]
# Let's look at the result:

# %%
src_all
# Out:
#          coord_ra  coord_dec     parentSourceId            x            y  \
# 0       53.201270 -27.841398                  0  3788.175341    28.706222
# 1       53.149934 -27.814036                  0  2834.245394    31.665411
# 2       53.003777 -27.735855                  0   114.431328    38.654726
# 3       53.007181 -27.738152                  0   182.264101    45.763033
# 4       53.074386 -27.774469                  0  1436.538958    47.768192
# ...           ...        ...                ...          ...          ...
# 197521  53.310490 -27.852761  25139291490354512  3018.873047  3943.664456
# 197522  53.309784 -27.854039  25139291490354512  2993.299978  3942.660105
# 197523  53.310774 -27.855343  25139291490354512  2978.196121  3966.536255
# 197524  53.316249 -27.840679  25139291490354515  3254.752492  3939.704297
# 197525  53.329890 -27.815522  25139291490354518  3756.623329  3955.542990
#
#             xErr      yErr         ra        dec     raErr  ...  \
# 0       1.856643  1.005068  53.201270 -27.841398  0.000082  ...
# 1       1.443259  1.008312  53.149934 -27.814036  0.000066  ...
# 2       0.502259  0.471090  53.003777 -27.735855  0.000024  ...
# 3       0.192874  0.188637  53.007181 -27.738152  0.000009  ...
# 4       0.031900  0.028608  53.074386 -27.774469  0.000002  ...
# ...          ...       ...        ...        ...       ...  ...
# 197521  0.147905  0.151178  53.310490 -27.852761  0.000007  ...
# 197522  0.264119  0.359438  53.309784 -27.854039  0.000017  ...
# 197523  0.579090  0.568027  53.310774 -27.855343  0.000028  ...
# 197524  1.496892  1.868746  53.316249 -27.840679  0.000089  ...
# 197525  0.031404  0.033872  53.329890 -27.815522  0.000002  ...
#
#         hsmShapeRegauss_flag_no_pixels  hsmShapeRegauss_flag_not_contained  \
# 0                                False                               False
# 1                                False                               False
# 2                                False                               False
# 3                                False                               False
# 4                                False                               False
# ...                                ...                                 ...
# 197521                           False                               False
# 197522                           False                               False
# 197523                           False                               False
# 197524                           False                               False
# 197525                           False                               False
#
#         hsmShapeRegauss_flag_parent_source  sky_source  detect_isPrimary  \
# 0                                    False       False              True
# 1                                    False       False              True
# 2                                    False       False              True
# 3                                    False       False              True
# 4                                    False       False              True
# ...                                    ...         ...               ...
# 197521                               False       False              True
# 197522                               False       False              True
# 197523                               False       False              True
# 197524                               False       False              True
# 197525                               False       False              True
#
#                 visit  detector  band  physical_filter           sourceId
# 0       2025090600260        44     z             z_20  25187647288770565
# 1       2025090600260        44     z             z_20  25187647288770566
# 2       2025090600260        44     z             z_20  25187647288770567
# 3       2025090600260        44     z             z_20  25187647288770568
# 4       2025090600260        44     z             z_20  25187647288770569
# ...               ...       ...   ...              ...                ...
# 197521  2025082600429       102     g              g_6  25139291490355113
# 197522  2025082600429       102     g              g_6  25139291490355114
# 197523  2025082600429       102     g              g_6  25139291490355115
# 197524  2025082600429       102     g              g_6  25139291490355117
# 197525  2025082600429       102     g              g_6  25139291490355119
#
# [197526 rows x 165 columns]

# %% [markdown]
# #### 3.2.4 Save `src_all` as a CSV file

# %% [markdown]
# Let's save `src_all` as a CSV file that we can download and examine with TOPCAT:
#
# ***(Rename this file to something else???)***

# %%
#src_all.to_csv('LSSTComCam_C26202_fields.csv', index=False)

# %% [markdown]
# ### 3.3 Extract only those rows containing C26202 from the src_all catalog

# %%
# Based on code retrieved from Claude-3.5-Sonnet

# Create a mask to cull sources with "bad" measurements.
mask = (~src_all.pixelFlags_bad) & (~src_all.pixelFlags_saturated) & \
        (~src_all.extendedness_flag) & (src_all.detect_isPrimary)

# Apply mask, keeping only the "good" measurements of `src_all`
src_all_cleaned = src_all[mask]

# Create SkyCoord object for the coordinates of C26202
ref_coord = SkyCoord(ra=raDeg*u.degree, dec=decDeg*u.degree)

# Create SkyCoord object for all points in the dataframe
df_coords = SkyCoord(ra=src_all_cleaned['ra'].values*u.degree, 
                     dec=src_all_cleaned['dec'].values*u.degree)

# Calculate separations
separations = ref_coord.separation(df_coords)

# Create mask for points within 3.0 arcseconds
mask_sep = separations < 3.0*u.arcsec

# Get filtered dataframe
nearby_good_df = src_all_cleaned[mask_sep]

# If you want to include the separations in the result
orig_columns = nearby_good_df.columns
nearby_good_df = src_all_cleaned[mask_sep].copy()
nearby_good_df['separation_c26202'] = separations[mask_sep].arcsec

# Find (and keep) the closet match within the match radius
best_df = nearby_good_df.sort_values('separation_c26202').drop_duplicates(subset=orig_columns, keep='first')

# %% [markdown]
# Add magCalib and magCalibErr columns:

# %%
# Flux in nano-Janskys to AB magnitudes:
best_df['magCalib'] = -2.5*np.log10(best_df['calibFlux']) + 31.4

# Flux error in nano-Janskys to AB magnitude error:
# Factor of 2.5/math.log(10) is explained here:  https://astronomy.stackexchange.com/questions/38371/how-can-i-calculate-the-uncertainties-in-magnitude-like-the-cds-does
best_df['magCalibErr'] = 2.5/math.log(10)*best_df['calibFluxErr']/best_df['calibFlux']

# %% [markdown]
# Display `visit`, `detector`, `band`, `calibFlux`, `calibFluxErr`, `magCalib`, `magCalibErr`, and `separation_c26202` from best_df, sorted by `visit` and `band`:

# %%
# Set pandas to show all rows...
pd.set_option("display.max_rows", None)

# %%
best_df[['visit', 'detector', 'band', 'calibFlux', 'calibFluxErr', 'magCalib', 'magCalibErr', 'separation_c26202']].sort_values(['visit', 'band'])
# Out:
#                 visit  detector band     calibFlux  calibFluxErr   magCalib  \
# 44039   2025071200713        92    r  1.032365e+06   1539.219360  16.365416
# 44780   2025071200714        92    r  1.032831e+06   1518.033813  16.364925
# 106831     0.001072           0.509653
# 108289     0.001078           0.499787
# 110339     0.001130           0.624546
# 112470     0.001136           0.591616
# 114428     0.001151           0.686580
# 116484     0.001143           0.567003
# 118535     0.001138           0.599765
# 120671     0.001133           0.610237
# 121552     0.002140           0.590926
# 122020     0.002611           0.614861
# 122462     0.002625           0.598491
# 123025     0.002016           0.625371
# 123573     0.002640           0.591099
# 124243     0.001926           0.581543
# 125053     0.003349           0.608169
# 126094     0.002712           0.624518
# 127058     0.003409           0.637817
# 128014     0.003199           0.631057
# 128992     0.003215           0.609846
# 130042     0.002806           0.604922
# 130636     0.002356           0.595833
# 131049     0.002283           0.638627
# 132120     0.001732           0.632639
# 133388     0.001651           0.634034
# 134768     0.001700           0.628059
# 135774     0.001788           0.619234
# 136783     0.001696           0.604723
# 138105     0.001670           0.641396
# 139504     0.001570           0.624350
# 140824     0.001631           0.597398
# 142082     0.001609           0.603476
# 143508     0.001593           0.657938
# 145008     0.001586           0.606856
# 147166     0.000899           0.619729
# 149514     0.000900           0.597239
# 151890     0.000901           0.614822
# 154388     0.000898           0.605838
# 157032     0.000897           0.622024
# 159751     0.000893           0.611008
# 16555      0.001680           0.636544
# 17542      0.001681           0.602569
# 18505      0.001672           0.632680
# 19469      0.001666           0.625590
# 20561      0.001648           0.602601
# 21722      0.001646           0.644068
# 162852     0.001156           0.614107
# 185370     0.001149           0.646803
# 54689      0.001150           0.618331
# 24636      0.001654           0.617694
# 56853      0.001677           0.614958
# 59199      0.001650           0.608151
# 172306     0.001658           0.620758
# 172569     0.000962           0.546096
# 192022     0.000971           0.577562
# 193376     0.000971           0.590646
# 195829     0.000983           0.581546
# 197277     0.001013           0.580593
# 31408      0.000987           0.600958
# 5345       0.000983           0.607775
# 33649      0.000985           0.615025
# 36011      0.000981           0.628305
# 7887       0.000981           0.600848
# 37323      0.000977           0.616031
# 1301       0.002224           0.654221
# 11152      0.002418           0.601623
# 9575       0.002219           0.611749
# 2393       0.002292           0.625747
# 60421      0.002281           0.598598
# 26152      0.002237           0.643230
# 154        0.002305           0.585379
# 65520      0.002432           0.569031
# 15478      0.002259           0.654515
# 39498      0.002261           0.608043
# 26941      0.002196           0.674655
# 59626      0.002192           0.636234
# 3013       0.002138           0.662428
# 61564      0.002201           0.627728
# 66221      0.002223           0.594723
# 27974      0.002193           0.613498
# 12280      0.002116           0.600280
# 66950      0.002117           0.613959
# 40217      0.002026           0.583991
# 62163      0.001994           0.558910
# 176555     0.001977           0.613174
# 67687      0.001971           0.614264
# 13532      0.002010           0.640405
# 15118      0.002155           0.605409
# 28550      0.002073           0.606105
# 177075     0.001957           0.608872
# 185638     0.001995           0.625393
# 177946     0.001974           0.597115
# 41302      0.001920           0.585050
# 13131      0.001919           0.606496

# %%
print("""Number of rows:  %d""" % (len(best_df['visit'])))
# Out:
# Number of rows:  125

# %%
# Reset pandas to its default maximum rows to print to screen
pd.reset_option("display.max_rows")

# %% [markdown]
# ***Do we need to do any further masking/culling in the above table before proceeding?***

# %% [markdown]
# ***Save to CSV file???***
#
# ***(How to name this file???)***

# %% [markdown]
# ### 3.4 Match pandas dataframe with observed ComCam magnitudes (best_df) with pandas dataframe with the synthetic magnitudes (df_mags)

# %%
# Reset the index to turn the keys into a column
df_mags_reset = df_mags.reset_index()

# Merge the dataframes based on the filter name
combined_df = pd.merge(best_df, df_mags_reset, left_on='band', right_on='index')

combined_df
# Out:
#       coord_ra  coord_dec  parentSourceId            x            y      xErr  \
# 0    53.136985 -27.863430               0   522.064200  3792.719250  0.005666
# 1    53.137003 -27.863465               0   529.107241  3793.459066  0.005810
# 2    53.136997 -27.863445               0   546.798690  3795.532800  0.007000
# 3    53.136995 -27.863440               0  1355.931346  2673.498290  0.005452
# 4    53.137001 -27.863452               0   547.681612  3796.244715  0.006848
# ..         ...        ...             ...          ...          ...       ...
# 120  53.137040 -27.863434               0  3574.705578   592.029231  0.009132
# 121  53.137041 -27.863433               0  1882.841992  3416.943092  0.006489
# 122  53.137039 -27.863425               0  1189.992274  2534.286755  0.007849
# 123  53.137042 -27.863423               0   141.636460  2385.127727  0.007827
# 124  53.137053 -27.863443               0   527.078818  3797.419047  0.004576
#
#          yErr         ra        dec         raErr  ...  detector  band  \
# 0    0.004915  53.136985 -27.863430  2.536553e-07  ...        95     g
# 1    0.004839  53.137003 -27.863465  2.536462e-07  ...        95     g
# 2    0.005803  53.136997 -27.863445  3.047599e-07  ...        95     g
# 3    0.006220  53.136995 -27.863440  3.050214e-07  ...        95     g
# 4    0.004838  53.137001 -27.863452  2.722312e-07  ...        95     g
# ..        ...        ...        ...           ...  ...       ...   ...
# 120  0.008043  53.137040 -27.863434  4.380855e-07  ...        86     z
# 121  0.006059  53.137041 -27.863433  3.081609e-07  ...        95     z
# 122  0.006248  53.137039 -27.863425  3.779700e-07  ...        51     z
# 123  0.006788  53.137042 -27.863423  3.771473e-07  ...        90     z
# 124  0.004180  53.137053 -27.863443  2.117146e-07  ...        95     i
#
#      physical_filter           sourceId  separation_c26202   magCalib  \
# 0                g_6  24980975234057503           0.499787  16.704973
# 1                g_6  24980975099839804           0.509653  16.703232
# 2                g_6  24980974697186363           0.514320  16.705679
# 3                g_6  24972185583485731           0.514953  16.701899
# 4                g_6  24980974562968665           0.516089  16.703228
# ..               ...                ...                ...        ...
# 120             z_20  25187647579226264           0.654515  16.237255
# 121             z_20  25011740219016273           0.657938  16.245270
# 122             z_20  25187648097747575           0.662428  16.245428
# 123             z_20  25187647849759270           0.674655  16.243467
# 124             i_39  24980975636710926           0.686580  16.239008
#
#      magCalibErr  index  stiswfcnic_007    mod_008
# 0       0.001078      g       16.691931  16.692687
# 1       0.001072      g       16.691931  16.692687
# 2       0.001107      g       16.691931  16.692687
# 3       0.001079      g       16.691931  16.692687
# 4       0.001094      g       16.691931  16.692687
# ..           ...    ...             ...        ...
# 120     0.002259      z       16.243679  16.243690
# 121     0.001593      z       16.243679  16.243690
# 122     0.002138      z       16.243679  16.243690
# 123     0.002196      z       16.243679  16.243690
# 124     0.001151      i       16.260196  16.259542
#
# [125 rows x 171 columns]

# %%
print(df_mags)
# Out:
#    stiswfcnic_007    mod_008
# u       17.572800  17.586964
# g       16.691931  16.692687
# r       16.362017  16.361654
# i       16.260196  16.259542
# z       16.243679  16.243690
# y       16.238847  16.238887

# %%
# Group by the 'band' column and calculate the median of 'magCalib' for each group
median_values = combined_df.groupby('band')['magCalib'].median().reset_index()
median_values = median_values.rename(columns={'magCalib': 'median_magCalib'})

# Merge the median values back into the combined_df dataframe
combined_df = pd.merge(combined_df, median_values, on='band', how='left')
combined_df
# Out:
#       coord_ra  coord_dec  parentSourceId            x            y      xErr  \
# 0    53.136985 -27.863430               0   522.064200  3792.719250  0.005666
# 1    53.137003 -27.863465               0   529.107241  3793.459066  0.005810
# 2    53.136997 -27.863445               0   546.798690  3795.532800  0.007000
# 3    53.136995 -27.863440               0  1355.931346  2673.498290  0.005452
# 4    53.137001 -27.863452               0   547.681612  3796.244715  0.006848
# ..         ...        ...             ...          ...          ...       ...
# 120  53.137040 -27.863434               0  3574.705578   592.029231  0.009132
# 121  53.137041 -27.863433               0  1882.841992  3416.943092  0.006489
# 122  53.137039 -27.863425               0  1189.992274  2534.286755  0.007849
# 123  53.137042 -27.863423               0   141.636460  2385.127727  0.007827
# 124  53.137053 -27.863443               0   527.078818  3797.419047  0.004576
#
#          yErr         ra        dec         raErr  ...  band  physical_filter  \
# 0    0.004915  53.136985 -27.863430  2.536553e-07  ...     g              g_6
# 1    0.004839  53.137003 -27.863465  2.536462e-07  ...     g              g_6
# 2    0.005803  53.136997 -27.863445  3.047599e-07  ...     g              g_6
# 3    0.006220  53.136995 -27.863440  3.050214e-07  ...     g              g_6
# 4    0.004838  53.137001 -27.863452  2.722312e-07  ...     g              g_6
# ..        ...        ...        ...           ...  ...   ...              ...
# 120  0.008043  53.137040 -27.863434  4.380855e-07  ...     z             z_20
# 121  0.006059  53.137041 -27.863433  3.081609e-07  ...     z             z_20
# 122  0.006248  53.137039 -27.863425  3.779700e-07  ...     z             z_20
# 123  0.006788  53.137042 -27.863423  3.771473e-07  ...     z             z_20
# 124  0.004180  53.137053 -27.863443  2.117146e-07  ...     i             i_39
#
#               sourceId  separation_c26202   magCalib  magCalibErr  index  \
# 0    24980975234057503           0.499787  16.704973     0.001078      g
# 1    24980975099839804           0.509653  16.703232     0.001072      g
# 2    24980974697186363           0.514320  16.705679     0.001107      g
# 3    24972185583485731           0.514953  16.701899     0.001079      g
# 4    24980974562968665           0.516089  16.703228     0.001094      g
# ..                 ...                ...        ...          ...    ...
# 120  25187647579226264           0.654515  16.237255     0.002259      z
# 121  25011740219016273           0.657938  16.245270     0.001593      z
# 122  25187648097747575           0.662428  16.245428     0.002138      z
# 123  25187647849759270           0.674655  16.243467     0.002196      z
# 124  24980975636710926           0.686580  16.239008     0.001151      i
#
#      stiswfcnic_007    mod_008  median_magCalib
# 0         16.691931  16.692687        16.701199
# 1         16.691931  16.692687        16.701199
# 2         16.691931  16.692687        16.701199
# 3         16.691931  16.692687        16.701199
# 4         16.691931  16.692687        16.701199
# ..              ...        ...              ...
# 120       16.243679  16.243690        16.243467
# 121       16.243679  16.243690        16.243467
# 122       16.243679  16.243690        16.243467
# 123       16.243679  16.243690        16.243467
# 124       16.260196  16.259542        16.242020
#
# [125 rows x 172 columns]

# %%
# Calculate the number of rows for each filter band
row_counts = combined_df.groupby('band').size().reset_index(name='n_total')

# Merge the row counts back into the combined_df dataframe
combined_df = pd.merge(combined_df, row_counts, on='band', how='left')

combined_df
# Out:
#       coord_ra  coord_dec  parentSourceId            x            y      xErr  \
# 0    53.136985 -27.863430               0   522.064200  3792.719250  0.005666
# 1    53.137003 -27.863465               0   529.107241  3793.459066  0.005810
# 2    53.136997 -27.863445               0   546.798690  3795.532800  0.007000
# 3    53.136995 -27.863440               0  1355.931346  2673.498290  0.005452
# 4    53.137001 -27.863452               0   547.681612  3796.244715  0.006848
# ..         ...        ...             ...          ...          ...       ...
# 120  53.137040 -27.863434               0  3574.705578   592.029231  0.009132
# 121  53.137041 -27.863433               0  1882.841992  3416.943092  0.006489
# 122  53.137039 -27.863425               0  1189.992274  2534.286755  0.007849
# 123  53.137042 -27.863423               0   141.636460  2385.127727  0.007827
# 124  53.137053 -27.863443               0   527.078818  3797.419047  0.004576
#
#          yErr         ra        dec         raErr  ...  physical_filter  \
# 0    0.004915  53.136985 -27.863430  2.536553e-07  ...              g_6
# 1    0.004839  53.137003 -27.863465  2.536462e-07  ...              g_6
# 2    0.005803  53.136997 -27.863445  3.047599e-07  ...              g_6
# 3    0.006220  53.136995 -27.863440  3.050214e-07  ...              g_6
# 4    0.004838  53.137001 -27.863452  2.722312e-07  ...              g_6
# ..        ...        ...        ...           ...  ...              ...
# 120  0.008043  53.137040 -27.863434  4.380855e-07  ...             z_20
# 121  0.006059  53.137041 -27.863433  3.081609e-07  ...             z_20
# 122  0.006248  53.137039 -27.863425  3.779700e-07  ...             z_20
# 123  0.006788  53.137042 -27.863423  3.771473e-07  ...             z_20
# 124  0.004180  53.137053 -27.863443  2.117146e-07  ...             i_39
#
#               sourceId  separation_c26202   magCalib  magCalibErr  index  \
# 0    24980975234057503           0.499787  16.704973     0.001078      g
# 1    24980975099839804           0.509653  16.703232     0.001072      g
# 2    24980974697186363           0.514320  16.705679     0.001107      g
# 3    24972185583485731           0.514953  16.701899     0.001079      g
# 4    24980974562968665           0.516089  16.703228     0.001094      g
# ..                 ...                ...        ...          ...    ...
# 120  25187647579226264           0.654515  16.237255     0.002259      z
# 121  25011740219016273           0.657938  16.245270     0.001593      z
# 122  25187648097747575           0.662428  16.245428     0.002138      z
# 123  25187647849759270           0.674655  16.243467     0.002196      z
# 124  24980975636710926           0.686580  16.239008     0.001151      i
#
#      stiswfcnic_007    mod_008  median_magCalib  n_total
# 0         16.691931  16.692687        16.701199       22
# 1         16.691931  16.692687        16.701199       22
# 2         16.691931  16.692687        16.701199       22
# 3         16.691931  16.692687        16.701199       22
# 4         16.691931  16.692687        16.701199       22
# ..              ...        ...              ...      ...
# 120       16.243679  16.243690        16.243467       37
# 121       16.243679  16.243690        16.243467       37
# 122       16.243679  16.243690        16.243467       37
# 123       16.243679  16.243690        16.243467       37
# 124       16.260196  16.259542        16.242020       36
#
# [125 rows x 173 columns]

# %%
# Calculate the differences and add the new columns
#combined_df['offset_stis'] = combined_df['median_magCalib_x'] - combined_df['stiswfcnic_007']
#combined_df['offset_mod'] = combined_df['median_magCalib_x'] - combined_df['mod_008']

#combined_df

# %% [markdown]
# **trying again - this time calculate the median then combine the tables for stis and mod**

# %%
# Calculate the number of rows for each filter band
row_counts = best_df.groupby('band').size().reset_index(name='n_band')

# Merge the row counts back into the combined_df dataframe
combined_df = pd.merge(best_df, row_counts, on='band', how='left')

combined_df
# Out:
#       coord_ra  coord_dec  parentSourceId            x            y      xErr  \
# 0    53.136985 -27.863430               0   522.064200  3792.719250  0.005666
# 1    53.137003 -27.863465               0   529.107241  3793.459066  0.005810
# 2    53.136997 -27.863445               0   546.798690  3795.532800  0.007000
# 3    53.136995 -27.863440               0  1355.931346  2673.498290  0.005452
# 4    53.137001 -27.863452               0   547.681612  3796.244715  0.006848
# ..         ...        ...             ...          ...          ...       ...
# 120  53.137040 -27.863434               0  3574.705578   592.029231  0.009132
# 121  53.137041 -27.863433               0  1882.841992  3416.943092  0.006489
# 122  53.137039 -27.863425               0  1189.992274  2534.286755  0.007849
# 123  53.137042 -27.863423               0   141.636460  2385.127727  0.007827
# 124  53.137053 -27.863443               0   527.078818  3797.419047  0.004576
#
#          yErr         ra        dec         raErr  ...  detect_isPrimary  \
# 0    0.004915  53.136985 -27.863430  2.536553e-07  ...              True
# 1    0.004839  53.137003 -27.863465  2.536462e-07  ...              True
# 2    0.005803  53.136997 -27.863445  3.047599e-07  ...              True
# 3    0.006220  53.136995 -27.863440  3.050214e-07  ...              True
# 4    0.004838  53.137001 -27.863452  2.722312e-07  ...              True
# ..        ...        ...        ...           ...  ...               ...
# 120  0.008043  53.137040 -27.863434  4.380855e-07  ...              True
# 121  0.006059  53.137041 -27.863433  3.081609e-07  ...              True
# 122  0.006248  53.137039 -27.863425  3.779700e-07  ...              True
# 123  0.006788  53.137042 -27.863423  3.771473e-07  ...              True
# 124  0.004180  53.137053 -27.863443  2.117146e-07  ...              True
#
#              visit  detector  band  physical_filter           sourceId  \
# 0    2025072100529        95     g              g_6  24980975234057503
# 1    2025072100528        95     g              g_6  24980975099839804
# 2    2025072100525        95     g              g_6  24980974697186363
# 3    2025071900577        95     g              g_6  24972185583485731
# 4    2025072100524        95     g              g_6  24980974562968665
# ..             ...       ...   ...              ...                ...
# 120  2025090600262        86     z             z_20  25187647579226264
# 121  2025072800370        95     z             z_20  25011740219016273
# 122  2025090600266        51     z             z_20  25187648097747575
# 123  2025090600264        90     z             z_20  25187647849759270
# 124  2025072100532        95     i             i_39  24980975636710926
#
#      separation_c26202   magCalib  magCalibErr  n_band
# 0             0.499787  16.704973     0.001078      22
# 1             0.509653  16.703232     0.001072      22
# 2             0.514320  16.705679     0.001107      22
# 3             0.514953  16.701899     0.001079      22
# 4             0.516089  16.703228     0.001094      22
# ..                 ...        ...          ...     ...
# 120           0.654515  16.237255     0.002259      37
# 121           0.657938  16.245270     0.001593      37
# 122           0.662428  16.245428     0.002138      37
# 123           0.674655  16.243467     0.002196      37
# 124           0.686580  16.239008     0.001151      36
#
# [125 rows x 169 columns]

# %%
# Group by the 'n_band' column and calculate the counts of 'band' for each group
count_df = best_df.groupby('band')['magCalib'].count().reset_index()

# Rename the columns for clarity
count_df = count_df.rename(columns={'magCalib': 'n_band'})

count_df
# Out:
#   band  n_band
# 0    g      22
# 1    i      36
# 2    r      30
# 3    z      37

# %%
# Group by the 'band' column and calculate the median of 'magCalib' for each group
median_df = best_df.groupby('band')['magCalib'].median().reset_index()

# Rename the columns for clarity
median_df = median_df.rename(columns={'magCalib': 'median_magCalib'})

median_df
# Out:
#   band  median_magCalib
# 0    g        16.701199
# 1    i        16.242020
# 2    r        16.362471
# 3    z        16.243467

# %%
# Merge the dataframes based on the filter name
combined_df = pd.merge(count_df, median_df, left_on='band', right_on='band')

combined_df
# Out:
#   band  n_band  median_magCalib
# 0    g      22        16.701199
# 1    i      36        16.242020
# 2    r      30        16.362471
# 3    z      37        16.243467

# %%
# Reset the index to turn the keys into a column
df_mags_reset = df_mags.reset_index()

# Merge the dataframes based on the filter name
combined_df = pd.merge(combined_df, df_mags_reset, left_on='band', right_on='index')

combined_df
# Out:
#   band  n_band  median_magCalib index  stiswfcnic_007    mod_008
# 0    g      22        16.701199     g       16.691931  16.692687
# 1    i      36        16.242020     i       16.260196  16.259542
# 2    r      30        16.362471     r       16.362017  16.361654
# 3    z      37        16.243467     z       16.243679  16.243690

# %%
# Calculate the differences and add the new columns
combined_df['offset_stis'] = combined_df['median_magCalib'] - combined_df['stiswfcnic_007']
combined_df['offset_mod'] = combined_df['median_magCalib'] - combined_df['mod_008']

combined_df
# Out:
#   band  n_band  median_magCalib index  stiswfcnic_007    mod_008  offset_stis  \
# 0    g      22        16.701199     g       16.691931  16.692687     0.009267
# 1    i      36        16.242020     i       16.260196  16.259542    -0.018176
# 2    r      30        16.362471     r       16.362017  16.361654     0.000453
# 3    z      37        16.243467     z       16.243679  16.243690    -0.000211
#
#    offset_mod
# 0    0.008511
# 1   -0.017522
# 2    0.000816
# 3   -0.000222

# %%
print(combined_df)
# Out:
#   band  n_band  median_magCalib index  stiswfcnic_007    mod_008  offset_stis  \
# 0    g      22        16.701199     g       16.691931  16.692687     0.009267
# 1    i      36        16.242020     i       16.260196  16.259542    -0.018176
# 2    r      30        16.362471     r       16.362017  16.361654     0.000453
# 3    z      37        16.243467     z       16.243679  16.243690    -0.000211
#
#    offset_mod
# 0    0.008511
# 1   -0.017522
# 2    0.000816
# 3   -0.000222

# %%
# Define the desired order of 'band'
order = ['u', 'g', 'r', 'i', 'z', 'y']

# Remove the 'index' column
combined_df = combined_df.drop(columns=['index'])

# Reorder the dataframe based on the 'band' column
combined_df['band'] = pd.Categorical(combined_df['band'], categories=order, ordered=True)
combined_df = combined_df.sort_values('band').reset_index(drop=True)

combined_df
# Out:
#   band  n_band  median_magCalib  stiswfcnic_007    mod_008  offset_stis  \
# 0    g      22        16.701199       16.691931  16.692687     0.009267
# 1    r      30        16.362471       16.362017  16.361654     0.000453
# 2    i      36        16.242020       16.260196  16.259542    -0.018176
# 3    z      37        16.243467       16.243679  16.243690    -0.000211
#
#    offset_mod
# 0    0.008511
# 1    0.000816
# 2   -0.017522
# 3   -0.000222

# %% [markdown]
# ***Save results to CSV file???***
#
# ***(How to name this file???)***

# %% [markdown]
# **Let's stop here for now:**

# %%
raise StopExecution

# %% [markdown]
# ## 4. Measure differences between the Observed ComCam and the LSST Synthetic Mags for C26202

# %% [markdown]
# ***Calculate statistics from the matched dataframe from Section 3 above.***

# %%
# DES DR2 AB offsets based on c26202_stisnic_007.fits from William Wester's DES-doc#15451...

print "AB offsets based on c26202_stisnic_007.fits"
print "==========================================="
print 

aboffset_i = i_wavg - i_ww
aboffset_gr = (g_wavg-r_wavg) - (g_ww-r_ww)
aboffset_ri = (r_wavg-i_wavg) - (r_ww-i_ww)
aboffset_iz = (i_wavg-z_wavg) - (i_ww-z_ww)
aboffset_zY = (z_wavg-Y_wavg) - (z_ww-Y_ww)

print "WAVG offsets"
print "------------"
print """i:    %10.4f""" % (aboffset_i)
print """g-r:  %10.4f""" % (aboffset_gr)
print """r-i:  %10.4f""" % (aboffset_ri)
print """i-z:  %10.4f""" % (aboffset_iz)
print """z-Y:  %10.4f""" % (aboffset_zY)
print 

aboffset_i = i_wavg - i_ww
aboffset_gr = (g_auto-r_auto) - (g_ww-r_ww)
aboffset_ri = (r_auto-i_auto) - (r_ww-i_ww)
aboffset_iz = (i_auto-z_auto) - (i_ww-z_ww)
aboffset_zY = (z_auto-Y_auto) - (z_ww-Y_ww)

print "MAG_AUTO offsets"
print "----------------"
print """i:    %10.4f""" % (aboffset_i)
print """g-r:  %10.4f""" % (aboffset_gr)
print """r-i:  %10.4f""" % (aboffset_ri)
print """i-z:  %10.4f""" % (aboffset_iz)
print """z-Y:  %10.4f""" % (aboffset_zY)
print

# %% [markdown]
# ## 5. Sandbox

# %%
datasetRefs = butler.query_datasets("visitSummary", where="visit_detector_region.region OVERLAPS POINT(ra, dec)",
                                    bind={"ra": raDeg, "dec": decDeg})

#print(datasetRefs)

print(f"\nFound {len(datasetRefs)} preliminary_visit_images")

# %%
# Retrieve sourceTable for this visit & detector...

datasetType = 'sourceTable'
#dataId = {'visit': visit, 'detector': detector}
dataId = ref.dataId['visit']
dataId = {'visit': ref.dataId['visit'], 'detector': ref.dataId['detector']}
print(dataId)

src = butler.get(datasetType, dataId=dataId)

print(f"Retrieved catalog of {len(src)} sources.")

# %%
butler.registry.queryDataIds(dimensions=('exposure'))

# %%
icExp = butler.get('icExp', dataId=dataId)

# %%
icExp_info = icExp.getInfo()

# %%
print(icExp_info.getMetadata())

# %%
print(dataId)

# %%
datasetRefs = butler.query_datasets("preliminary_visit_image", where="visit_detector_region.region OVERLAPS POINT(ra, dec)",
                                    bind={"ra": raDeg, "dec": decDeg})

# %%
for dt in sorted(butler.registry.queryDatasetTypes('*src*')):
    print(dt)

# %%
for dt in sorted(butler.registry.queryDatasetTypes('*icSrc*')):
    print(dt)

# %%
icSrc = butler.get('icSrc', dataId=dataId)

# %%
icSrc.asAstropy()

# %%
src1 = butler.get('src', dataId=dataId)

# %%
src1.asAstropy()
