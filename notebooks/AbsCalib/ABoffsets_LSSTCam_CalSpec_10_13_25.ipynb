# %% [markdown]
# # ABoffsets_LSSTComCam_c26202
#
# Authors:  C. L. Adair, D. L. Tucker, with help from L. Jones, J. Carlin, and others
#
# Created:  2024.11.15
# Updated: 2025.10.14

# %% [markdown]
# ## 1. Initial Setup...

# %% [markdown]
# ### 1.1 Import useful python packages

# %%
# Generic python packages
import pylab as plt
import numpy as np
import pandas as pd
import glob
import math
import os
import gc
import warnings

# LSST Science Pipelines (Stack) packages
import lsst.daf.butler as dafButler
import lsst.afw.display as afwDisplay

# rubin_sim-related packages
import rubin_sim.phot_utils as pt
import syseng_throughputs as st
from rubin_sim.data import get_data_dir

# Astropy-related packages
from astropy import units as u
from astropy.io import fits
from astropy.coordinates import SkyCoord
import lsst.geom as geom

# Set a standard figure size to use
plt.rcParams['figure.figsize'] = (8.0, 8.0)
afwDisplay.setDefaultBackend('matplotlib')

# Set filter warnings to "ignore" to avoid a lot of "logorrhea" to the screen:
warnings.filterwarnings("ignore")
# Out:
# /home/d/dltucker/WORK/GitHub/syseng_throughputs/syseng_throughputs/bandpassUtils.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ### 1.2 Include user input

# %%
# Which repo, collection, instrument, and skymap to use.
# See https://rubinobs.atlassian.net/wiki/spaces/DM/pages/48834013/Campaigns#1.1.-ComCam
# and https://rubinobs.atlassian.net/wiki/spaces/DM/pages/226656354/LSSTComCam+Intermittent+Cumulative+DRP+Runs
#repo = 'embargo'
#repo = '/repo/dp1'
repo = '/repo/main'
#collections = 'LSSTComCam/runs/DRP/DP1/v29_0_0/DM-50260'
collections = 'LSSTCam/runs/DRP/20250604_20250921/w_2025_39/DM-52645'

#instrument = 'LSSTComCam'
instrument = 'LSSTCam'
skymap_name = 'lsst_cells_v1'
#day_obs_start = 20241101
#day_obs_end = 20241231
day_obs_start = 20250401
day_obs_end = 20251230
plotImages = False
plotCutouts = False

# Set environment variable to point to location of the rubin_sim_data 
#  (per Lynne Jones' Slack message on the #sciunit-photo-calib channel from 26 Nov 2024):
os.environ["RUBIN_SIM_DATA_DIR"] = "/sdf/data/rubin/shared/rubin_sim_data"


# calspec filename
calspec_filename = "./mag_CalSpec.csv"
#Star_Name = Star_Name
#Star_Name = "WDFS1930-52"
#Star_Name = "NGC6681-1"
#Star_Name = "WDFS1514+00"
#Star_Name = "WDFS1206-27"
#Star_Name = "VB8"
#Star_Name = "WDFS1055-36"
#Star_Name = "WDFS1837-70"
Star_Name = "C26202"
#Star_Name = "WDFS2317-29"
#Star_Name = "WDFS1434-28"
#Star_Name = "WDFS1535-77"


# DA Stars--------------------------------------------------------------------------------
###########################################################################################

# WDFS1930-52

# RA, DEC in degrees:
# raDeg = 292.57899
# decDeg = -52.06278
# sedfile_dict = {'stis_001' : '~/Downloads/wdfs1930_52_stis_001.fits'
#                'mod_001'        : '~/Downloads/wdfs1930_52_mod_001.fits'
#               }




# List of filters to examine
flist = ['u','g','r','i','z','y']

# Plot symbol colors to use for ugrizy
plot_filter_colors_white_background = {'u': '#0c71ff', 'g': '#49be61', 'r': '#c61c00', 'i': '#ffc200', 'z': '#f341a2', 'y': '#5d0000'}

# %%
# DA Stars--------------------------------------------------------------------------------
###########################################################################################

# WDFS1930-52

# RA, DEC in degrees:
# raDeg = 292.57899
# decDeg = -52.06278
# sedfile_dict = {'stis_001' : '~/Downloads/wdfs1930_52_stis_001.fits'
#                'mod_001'        : '~/Downloads/wdfs1930_52_mod_001.fits'
#               }

# Read CSV into a DataFrame
df = pd.read_csv(calspec_filename)

# Convert to list of dictionaries
data = df.to_dict(orient="records")

# Or: dictionary of dictionaries keyed by Star_Name
data_by_star = df.set_index("Star_Name").to_dict(orient="index")

print(data_by_star[Star_Name])


raDeg = data_by_star[Star_Name]["raDeg"]
decDeg = data_by_star[Star_Name]["decDeg"]




downloads_path = os.path.expanduser("~/Downloads")

# Grab the row dictionary for this star
row = data_by_star[Star_Name]

# Build dictionary of file names
sedfile_dict = {}

# Loop over the last three columns
for col in ["STIS", "Model"]:
    val = row[col]
    if pd.notna(val) and val != "":
        # strip leading underscore if present
        key = val.strip("_")
        filename = f"{row['Name']}_{key}.fits"
        sedfile_dict[key] = os.path.join(downloads_path, filename)

print(sedfile_dict)
# Out:
# {'RAHMS': '03 32 32.843', 'DECDMS': '-27 51 48.58', 'raDeg': 53.13684583333333, 'decDeg': -27.863494444444445, 'Vr': nan, 'PM_RA': nan, 'PM_DEC': nan, 'Simbad_Name': '2MASS J03323287-2751483', 'Alt_Simbad_Name': '[B2010] C26202', 'Sp_T': 'F8IV', 'G_Gaia': nan, 'V': 16.64, 'BV': 0.26, 'Name': 'c26202', 'Model': '_mod_008', 'STIS': '_stiswfcnic_007'}
# {'stiswfcnic_007': '/home/d/dltucker/Downloads/c26202_stiswfcnic_007.fits', 'mod_008': '/home/d/dltucker/Downloads/c26202_mod_008.fits'}

# %% [markdown]
# ### 1.3 Define useful classes and functions

# %%
# Useful class to stop "Run All" at a cell 
#  containing the command "raise StopExecution"
class StopExecution(Exception):
    def _render_traceback_(self):
        pass

# %%
def cutout_im(butler, ra, dec, datasetType, visit, detector, cutoutSideLength=51, **kwargs):
    
    """
    Produce a cutout from a preliminary_visit_image at the given ra, dec position.

    Adapted from cutout_coadd which was adapted from a DC2 tutorial
    notebook by Michael Wood-Vasey.

    """
    
    dataId = {'visit': visit, 'detector': detector}    
    radec = geom.SpherePoint(ra, dec, geom.degrees)
    cutoutSize = geom.ExtentI(cutoutSideLength, cutoutSideLength)
    wcs = butler.get('%s.wcs' % datasetType,**dataId)
    xy = geom.PointI(wcs.skyToPixel(radec))
    bbox = geom.BoxI(xy - cutoutSize // 2, cutoutSize)
    parameters = {'bbox': bbox}
    cutout_image = butler.get(datasetType, parameters=parameters, **dataId)

    return cutout_image

# %%
def warp_img(ref_img, img_to_warp, ref_wcs, wcs_to_warp):

    config = RegisterConfig()
    task = RegisterTask(name="register", config=config)
    warpedExp = task.warpExposure(img_to_warp, wcs_to_warp, ref_wcs,
                                  ref_img.getBBox())

    return warpedExp

# %%
def make_gif(frame_folder):
    frames = [Image.open(image) for image in sorted(glob.glob(f"{frame_folder}/*.png"))]
    frame_one = frames[0]
    frame_one.save("animation.gif", format="GIF", append_images=frames,
               save_all=True, duration=500, loop = 0)

# %% [markdown]
# ## 2. Calculate Synthetic AB magnitudes for C26202, based on official filter bandpasses

# %% [markdown]
# ### 2.1 Change detectors from (default) LSST to ComCam

# %%
defaultDirs = st.setDefaultDirs()
defaultDirs['detector'] = defaultDirs['detector'].replace('/joint_minimum', '/itl')
hardware, system = st.buildHardwareAndSystem(defaultDirs)

# %% [markdown]
# ### 2.2 Calculate synthetic mags

# %%
mags = {}

# Loop through all SEDs in our sedfile dictionary
for sed_key in sedfile_dict:
    
    print(sed_key, sedfile_dict[sed_key])
    
    # Read the SED file associated with this SED
    sedfile = sedfile_dict[sed_key]
    seddata = fits.getdata(sedfile)

    # Transform the SED data into rubin_sim format
    wavelen = seddata['WAVELENGTH'] * u.angstrom.to(u.nanometer) # This is in angstroms - need in nanometers
    flambda = seddata['FLUX'] / (u.angstrom.to(u.nanometer)) # this is in erg/sec/cm^^2/ang but we want /nm     
    sed = pt.Sed(wavelen=wavelen, flambda=flambda)
    
    # Loop over the filters, calculating the synthetic mags for each filter for this SED
    mags[sed_key] = []
    for f in flist:
        # Append the synthetic mag for this filter to this mags list for this SED
        mags[sed_key].append(sed.calc_mag(system[f]))
    # Convert list of synthetic mags for this SED into a numpy array
    mags[sed_key] = np.array(mags[sed_key])
# Out:
# stiswfcnic_007 /home/d/dltucker/Downloads/c26202_stiswfcnic_007.fits
# mod_008 /home/d/dltucker/Downloads/c26202_mod_008.fits

# %% [markdown]
# ### 2.3 Convert mags numpy arrays into a pandas dataframe

# %%
df_mags = pd.DataFrame(mags, index=flist)
df_mags
# Out:
#    stiswfcnic_007    mod_008
# u       17.572800  17.586964
# g       16.691931  16.692687
# r       16.362017  16.361654
# i       16.260196  16.259542
# z       16.243679  16.243690
# y       16.238847  16.238887

# %% [markdown]
# ## 3. Query USDF Butler for ComCam measurements of C26202

# %% [markdown]
# ### 3.1 Instantiate Butler

# %%
butler = dafButler.Butler(repo, collections=collections)

# %% [markdown]
# ### 3.2 Find all the `preliminary_visit_image`'s that overlap the sky position of C26202

# %% [markdown]
# #### 3.2.1 Find the `dataId`'s for all `preliminary_visit_image`'s in this repo/collection that overlap the RA, DEC of C26202

# %%
datasetRefs = butler.query_datasets("visit_image", where="visit_detector_region.region OVERLAPS POINT(ra, dec)",
                                    bind={"ra": raDeg, "dec": decDeg})

for i, ref in enumerate(datasetRefs):    
    print(i, ref.dataId)

print(f"\nFound {len(datasetRefs)} preliminary_visit_images")
# Out:
# 0 {instrument: 'LSSTCam', detector: 44, visit: 2025090600260, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 1 {instrument: 'LSSTCam', detector: 49, visit: 2025090600252, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 2 {instrument: 'LSSTCam', detector: 51, visit: 2025090600256, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 3 {instrument: 'LSSTCam', detector: 51, visit: 2025090600266, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 4 {instrument: 'LSSTCam', detector: 51, visit: 2025090600280, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 5 {instrument: 'LSSTCam', detector: 52, visit: 2025082600442, band: 'i', day_obs: 20250826, physical_filter: 'i_39'}
# 6 {instrument: 'LSSTCam', detector: 52, visit: 2025082600445, band: 'i', day_obs: 20250826, physical_filter: 'i_39'}
# 7 {instrument: 'LSSTCam', detector: 52, visit: 2025090600254, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 8 {instrument: 'LSSTCam', detector: 52, visit: 2025090600259, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 9 {instrument: 'LSSTCam', detector: 53, visit: 2025090600253, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 10 {instrument: 'LSSTCam', detector: 53, visit: 2025090600270, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 11 {instrument: 'LSSTCam', detector: 53, visit: 2025090600285, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 12 {instrument: 'LSSTCam', detector: 60, visit: 2025090600277, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 13 {instrument: 'LSSTCam', detector: 61, visit: 2025090600274, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 14 {instrument: 'LSSTCam', detector: 61, visit: 2025090600278, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 15 {instrument: 'LSSTCam', detector: 86, visit: 2025090600262, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 16 {instrument: 'LSSTCam', detector: 90, visit: 2025081000328, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 17 {instrument: 'LSSTCam', detector: 90, visit: 2025081000329, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 18 {instrument: 'LSSTCam', detector: 90, visit: 2025081000330, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 19 {instrument: 'LSSTCam', detector: 90, visit: 2025081000331, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 20 {instrument: 'LSSTCam', detector: 90, visit: 2025081000332, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 21 {instrument: 'LSSTCam', detector: 90, visit: 2025081000333, band: 'i', day_obs: 20250810, physical_filter: 'i_39'}
# 22 {instrument: 'LSSTCam', detector: 90, visit: 2025081300332, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 23 {instrument: 'LSSTCam', detector: 90, visit: 2025090600255, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 24 {instrument: 'LSSTCam', detector: 90, visit: 2025090600258, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 25 {instrument: 'LSSTCam', detector: 90, visit: 2025090600264, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 26 {instrument: 'LSSTCam', detector: 90, visit: 2025090600269, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 27 {instrument: 'LSSTCam', detector: 90, visit: 2025090600279, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 28 {instrument: 'LSSTCam', detector: 90, visit: 2025090600280, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 29 {instrument: 'LSSTCam', detector: 91, visit: 2025082600441, band: 'i', day_obs: 20250826, physical_filter: 'i_39'}
# 30 {instrument: 'LSSTCam', detector: 91, visit: 2025082600443, band: 'i', day_obs: 20250826, physical_filter: 'i_39'}
# 31 {instrument: 'LSSTCam', detector: 91, visit: 2025082600444, band: 'i', day_obs: 20250826, physical_filter: 'i_39'}
# 32 {instrument: 'LSSTCam', detector: 91, visit: 2025082600446, band: 'i', day_obs: 20250826, physical_filter: 'i_39'}
# 33 {instrument: 'LSSTCam', detector: 91, visit: 2025090600263, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 34 {instrument: 'LSSTCam', detector: 91, visit: 2025090600272, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 35 {instrument: 'LSSTCam', detector: 91, visit: 2025090600279, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 36 {instrument: 'LSSTCam', detector: 91, visit: 2025090600284, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 37 {instrument: 'LSSTCam', detector: 92, visit: 2025071100809, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 38 {instrument: 'LSSTCam', detector: 92, visit: 2025071100810, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 39 {instrument: 'LSSTCam', detector: 92, visit: 2025071100811, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 40 {instrument: 'LSSTCam', detector: 92, visit: 2025071100812, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 41 {instrument: 'LSSTCam', detector: 92, visit: 2025071100819, band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 42 {instrument: 'LSSTCam', detector: 92, visit: 2025071100820, band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 43 {instrument: 'LSSTCam', detector: 92, visit: 2025071200713, band: 'r', day_obs: 20250712, physical_filter: 'r_57'}
# 44 {instrument: 'LSSTCam', detector: 92, visit: 2025071200714, band: 'r', day_obs: 20250712, physical_filter: 'r_57'}
# 45 {instrument: 'LSSTCam', detector: 92, visit: 2025071200735, band: 'z', day_obs: 20250712, physical_filter: 'z_20'}
# 46 {instrument: 'LSSTCam', detector: 92, visit: 2025071200736, band: 'z', day_obs: 20250712, physical_filter: 'z_20'}
# 47 {instrument: 'LSSTCam', detector: 92, visit: 2025071200737, band: 'z', day_obs: 20250712, physical_filter: 'z_20'}
# 48 {instrument: 'LSSTCam', detector: 92, visit: 2025071200738, band: 'z', day_obs: 20250712, physical_filter: 'z_20'}
# 49 {instrument: 'LSSTCam', detector: 92, visit: 2025071200739, band: 'z', day_obs: 20250712, physical_filter: 'z_20'}
# 50 {instrument: 'LSSTCam', detector: 92, visit: 2025081300306, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 51 {instrument: 'LSSTCam', detector: 92, visit: 2025081300310, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 52 {instrument: 'LSSTCam', detector: 92, visit: 2025081300334, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 53 {instrument: 'LSSTCam', detector: 92, visit: 2025081300336, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 54 {instrument: 'LSSTCam', detector: 92, visit: 2025090600265, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 55 {instrument: 'LSSTCam', detector: 93, visit: 2025090600257, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 56 {instrument: 'LSSTCam', detector: 93, visit: 2025090600267, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 57 {instrument: 'LSSTCam', detector: 93, visit: 2025090600273, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 58 {instrument: 'LSSTCam', detector: 94, visit: 2025081300333, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 59 {instrument: 'LSSTCam', detector: 94, visit: 2025090600261, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 60 {instrument: 'LSSTCam', detector: 94, visit: 2025090600268, band: 'z', day_obs: 20250906, physical_filter: 'z_20'}
# 61 {instrument: 'LSSTCam', detector: 94, visit: 2025090600271, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 62 {instrument: 'LSSTCam', detector: 94, visit: 2025090600276, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 63 {instrument: 'LSSTCam', detector: 95, visit: 2025071700593, band: 'g', day_obs: 20250717, physical_filter: 'g_6'}
# 64 {instrument: 'LSSTCam', detector: 95, visit: 2025071700594, band: 'g', day_obs: 20250717, physical_filter: 'g_6'}
# 65 {instrument: 'LSSTCam', detector: 95, visit: 2025071700595, band: 'g', day_obs: 20250717, physical_filter: 'g_6'}
# 66 {instrument: 'LSSTCam', detector: 95, visit: 2025071700602, band: 'i', day_obs: 20250717, physical_filter: 'i_39'}
# 67 {instrument: 'LSSTCam', detector: 95, visit: 2025071700603, band: 'i', day_obs: 20250717, physical_filter: 'i_39'}
# 68 {instrument: 'LSSTCam', detector: 95, visit: 2025071700604, band: 'i', day_obs: 20250717, physical_filter: 'i_39'}
# 69 {instrument: 'LSSTCam', detector: 95, visit: 2025071700605, band: 'i', day_obs: 20250717, physical_filter: 'i_39'}
# 70 {instrument: 'LSSTCam', detector: 95, visit: 2025071700606, band: 'i', day_obs: 20250717, physical_filter: 'i_39'}
# 71 {instrument: 'LSSTCam', detector: 95, visit: 2025071700607, band: 'i', day_obs: 20250717, physical_filter: 'i_39'}
# 72 {instrument: 'LSSTCam', detector: 95, visit: 2025071900574, band: 'i', day_obs: 20250719, physical_filter: 'i_39'}
# 73 {instrument: 'LSSTCam', detector: 95, visit: 2025071900575, band: 'g', day_obs: 20250719, physical_filter: 'g_6'}
# 74 {instrument: 'LSSTCam', detector: 95, visit: 2025071900576, band: 'g', day_obs: 20250719, physical_filter: 'g_6'}
# 75 {instrument: 'LSSTCam', detector: 95, visit: 2025071900577, band: 'g', day_obs: 20250719, physical_filter: 'g_6'}
# 76 {instrument: 'LSSTCam', detector: 95, visit: 2025071900578, band: 'g', day_obs: 20250719, physical_filter: 'g_6'}
# 77 {instrument: 'LSSTCam', detector: 95, visit: 2025071900579, band: 'g', day_obs: 20250719, physical_filter: 'g_6'}
# 78 {instrument: 'LSSTCam', detector: 95, visit: 2025071900580, band: 'g', day_obs: 20250719, physical_filter: 'g_6'}
# 79 {instrument: 'LSSTCam', detector: 95, visit: 2025071900586, band: 'i', day_obs: 20250719, physical_filter: 'i_39'}
# 80 {instrument: 'LSSTCam', detector: 95, visit: 2025071900587, band: 'i', day_obs: 20250719, physical_filter: 'i_39'}
# 81 {instrument: 'LSSTCam', detector: 95, visit: 2025071900588, band: 'i', day_obs: 20250719, physical_filter: 'i_39'}
# 82 {instrument: 'LSSTCam', detector: 95, visit: 2025071900589, band: 'i', day_obs: 20250719, physical_filter: 'i_39'}
# 83 {instrument: 'LSSTCam', detector: 95, visit: 2025071900590, band: 'i', day_obs: 20250719, physical_filter: 'i_39'}
# 84 {instrument: 'LSSTCam', detector: 95, visit: 2025072100524, band: 'g', day_obs: 20250721, physical_filter: 'g_6'}
# 85 {instrument: 'LSSTCam', detector: 95, visit: 2025072100525, band: 'g', day_obs: 20250721, physical_filter: 'g_6'}
# 86 {instrument: 'LSSTCam', detector: 95, visit: 2025072100526, band: 'g', day_obs: 20250721, physical_filter: 'g_6'}
# 87 {instrument: 'LSSTCam', detector: 95, visit: 2025072100527, band: 'g', day_obs: 20250721, physical_filter: 'g_6'}
# 88 {instrument: 'LSSTCam', detector: 95, visit: 2025072100528, band: 'g', day_obs: 20250721, physical_filter: 'g_6'}
# 89 {instrument: 'LSSTCam', detector: 95, visit: 2025072100529, band: 'g', day_obs: 20250721, physical_filter: 'g_6'}
# 90 {instrument: 'LSSTCam', detector: 95, visit: 2025072100530, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 91 {instrument: 'LSSTCam', detector: 95, visit: 2025072100531, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 92 {instrument: 'LSSTCam', detector: 95, visit: 2025072100532, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 93 {instrument: 'LSSTCam', detector: 95, visit: 2025072100533, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 94 {instrument: 'LSSTCam', detector: 95, visit: 2025072100534, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 95 {instrument: 'LSSTCam', detector: 95, visit: 2025072100535, band: 'i', day_obs: 20250721, physical_filter: 'i_39'}
# 96 {instrument: 'LSSTCam', detector: 95, visit: 2025072200465, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 97 {instrument: 'LSSTCam', detector: 95, visit: 2025072200466, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 98 {instrument: 'LSSTCam', detector: 95, visit: 2025072200467, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 99 {instrument: 'LSSTCam', detector: 95, visit: 2025072200468, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 100 {instrument: 'LSSTCam', detector: 95, visit: 2025072200469, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 101 {instrument: 'LSSTCam', detector: 95, visit: 2025072200470, band: 'r', day_obs: 20250722, physical_filter: 'r_57'}
# 102 {instrument: 'LSSTCam', detector: 95, visit: 2025072200474, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 103 {instrument: 'LSSTCam', detector: 95, visit: 2025072200478, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 104 {instrument: 'LSSTCam', detector: 95, visit: 2025072200479, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 105 {instrument: 'LSSTCam', detector: 95, visit: 2025072200480, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 106 {instrument: 'LSSTCam', detector: 95, visit: 2025072200481, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 107 {instrument: 'LSSTCam', detector: 95, visit: 2025072200482, band: 'z', day_obs: 20250722, physical_filter: 'z_20'}
# 108 {instrument: 'LSSTCam', detector: 95, visit: 2025072300437, band: 'g', day_obs: 20250723, physical_filter: 'g_6'}
# 109 {instrument: 'LSSTCam', detector: 95, visit: 2025072300438, band: 'g', day_obs: 20250723, physical_filter: 'g_6'}
# 110 {instrument: 'LSSTCam', detector: 95, visit: 2025072300445, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 111 {instrument: 'LSSTCam', detector: 95, visit: 2025072300446, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 112 {instrument: 'LSSTCam', detector: 95, visit: 2025072300447, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 113 {instrument: 'LSSTCam', detector: 95, visit: 2025072300448, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 114 {instrument: 'LSSTCam', detector: 95, visit: 2025072300449, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 115 {instrument: 'LSSTCam', detector: 95, visit: 2025072300450, band: 'i', day_obs: 20250723, physical_filter: 'i_39'}
# 116 {instrument: 'LSSTCam', detector: 95, visit: 2025072800366, band: 'z', day_obs: 20250728, physical_filter: 'z_20'}
# 117 {instrument: 'LSSTCam', detector: 95, visit: 2025072800368, band: 'z', day_obs: 20250728, physical_filter: 'z_20'}
# 118 {instrument: 'LSSTCam', detector: 95, visit: 2025072800369, band: 'z', day_obs: 20250728, physical_filter: 'z_20'}
# 119 {instrument: 'LSSTCam', detector: 95, visit: 2025072800370, band: 'z', day_obs: 20250728, physical_filter: 'z_20'}
# 120 {instrument: 'LSSTCam', detector: 95, visit: 2025072800371, band: 'z', day_obs: 20250728, physical_filter: 'z_20'}
# 121 {instrument: 'LSSTCam', detector: 95, visit: 2025072800396, band: 'r', day_obs: 20250728, physical_filter: 'r_57'}
# 122 {instrument: 'LSSTCam', detector: 95, visit: 2025072800397, band: 'r', day_obs: 20250728, physical_filter: 'r_57'}
# 123 {instrument: 'LSSTCam', detector: 95, visit: 2025072800398, band: 'r', day_obs: 20250728, physical_filter: 'r_57'}
# 124 {instrument: 'LSSTCam', detector: 95, visit: 2025072800399, band: 'r', day_obs: 20250728, physical_filter: 'r_57'}
# 125 {instrument: 'LSSTCam', detector: 95, visit: 2025072800400, band: 'r', day_obs: 20250728, physical_filter: 'r_57'}
# 126 {instrument: 'LSSTCam', detector: 95, visit: 2025072800401, band: 'r', day_obs: 20250728, physical_filter: 'r_57'}
# 127 {instrument: 'LSSTCam', detector: 95, visit: 2025081300305, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 128 {instrument: 'LSSTCam', detector: 95, visit: 2025081300307, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 129 {instrument: 'LSSTCam', detector: 95, visit: 2025081300309, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 130 {instrument: 'LSSTCam', detector: 95, visit: 2025081300333, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 131 {instrument: 'LSSTCam', detector: 95, visit: 2025081300335, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 132 {instrument: 'LSSTCam', detector: 95, visit: 2025081300337, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 133 {instrument: 'LSSTCam', detector: 95, visit: 2025082600425, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
# 134 {instrument: 'LSSTCam', detector: 95, visit: 2025082600430, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
# 135 {instrument: 'LSSTCam', detector: 98, visit: 2025090600275, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 136 {instrument: 'LSSTCam', detector: 98, visit: 2025090600281, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 137 {instrument: 'LSSTCam', detector: 98, visit: 2025090600283, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 138 {instrument: 'LSSTCam', detector: 99, visit: 2025071100809, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 139 {instrument: 'LSSTCam', detector: 99, visit: 2025071100810, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 140 {instrument: 'LSSTCam', detector: 99, visit: 2025071100811, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 141 {instrument: 'LSSTCam', detector: 99, visit: 2025071100812, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 142 {instrument: 'LSSTCam', detector: 99, visit: 2025071100814, band: 'g', day_obs: 20250711, physical_filter: 'g_6'}
# 143 {instrument: 'LSSTCam', detector: 99, visit: 2025071100816, band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 144 {instrument: 'LSSTCam', detector: 99, visit: 2025071100817, band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 145 {instrument: 'LSSTCam', detector: 99, visit: 2025071100818, band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 146 {instrument: 'LSSTCam', detector: 99, visit: 2025071100819, band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 147 {instrument: 'LSSTCam', detector: 99, visit: 2025071100820, band: 'i', day_obs: 20250711, physical_filter: 'i_39'}
# 148 {instrument: 'LSSTCam', detector: 99, visit: 2025081300308, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 149 {instrument: 'LSSTCam', detector: 99, visit: 2025090600282, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 150 {instrument: 'LSSTCam', detector: 100, visit: 2025090600274, band: 'r', day_obs: 20250906, physical_filter: 'r_57'}
# 151 {instrument: 'LSSTCam', detector: 102, visit: 2025081300309, band: 'r', day_obs: 20250813, physical_filter: 'r_57'}
# 152 {instrument: 'LSSTCam', detector: 102, visit: 2025081300337, band: 'z', day_obs: 20250813, physical_filter: 'z_20'}
# 153 {instrument: 'LSSTCam', detector: 102, visit: 2025082600426, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
# 154 {instrument: 'LSSTCam', detector: 102, visit: 2025082600427, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
# 155 {instrument: 'LSSTCam', detector: 102, visit: 2025082600428, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
# 156 {instrument: 'LSSTCam', detector: 102, visit: 2025082600429, band: 'g', day_obs: 20250826, physical_filter: 'g_6'}
#
# Found 157 preliminary_visit_images

# %% [markdown]
# #### 3.2.3 Create a pandas Dataframe containing the `source2` info for all these `visit_image`'s

# %% [markdown]
# Now, loop over the `datasetRefs` again, but this time grab the contents of the `sourceTable` table for each `ref` and combine into all into one big pandas DataFrame.

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u
import pandas as pd

# Reference CALSPEC star coordinates
ref_coord = SkyCoord(ra=raDeg*u.degree, dec=decDeg*u.degree)

src_list = []

for i, ref in enumerate(datasetRefs):
    dataId = {'visit': ref.dataId['visit'], 'detector': ref.dataId['detector']}
    src = butler.get('source2', dataId=dataId).to_pandas()
#    src = butler.get('recalibrated_star_detector', dataId=dataId).to_pandas()
# NOTE - source2 has more matches and gives a slightly different offset to recalibrated - which is going away soon (less than 2 mmag)

    # Apply "good measurement" mask immediately
    mask = (~src.pixelFlags_bad) & (~src.pixelFlags_saturated) & \
           (~src.extendedness_flag)
    src_cleaned = src[mask]

    # Compute separations to CALSPEC star
    df_coords = SkyCoord(ra=src_cleaned['ra'].values*u.degree,
                         dec=src_cleaned['dec'].values*u.degree)
    separations = ref_coord.separation(df_coords)

    # Keep only sources within 3 arcsec
    mask_sep = separations < 3.0*u.arcsec
    nearby = src_cleaned[mask_sep].copy()
    nearby['separation_c26202'] = separations[mask_sep].arcsec

    
    if not nearby.empty:
        best = nearby.sort_values('separation_c26202').iloc[[0]]
        src_list.append(best)
        print(f"{i} Visit {ref.dataId['visit']}, Detector {ref.dataId['detector']}: "
              f"Found {len(best)} candidate matches.")

# Concatenate only the small filtered tables
if src_list:
    src_all = pd.concat(src_list, ignore_index=True)
    print(f"\nTotal combined catalog contains {len(src_all)} candidate sources.")
else:
    print("No matches found within 3 arcsec.")

best_df = src_all
# Out:
# 0 Visit 2025090600260, Detector 44: Found 1 candidate matches.
# 1 Visit 2025090600252, Detector 49: Found 1 candidate matches.
# 2 Visit 2025090600256, Detector 51: Found 1 candidate matches.
# 3 Visit 2025090600266, Detector 51: Found 1 candidate matches.
# 5 Visit 2025082600442, Detector 52: Found 1 candidate matches.
# 6 Visit 2025082600445, Detector 52: Found 1 candidate matches.
# 7 Visit 2025090600254, Detector 52: Found 1 candidate matches.
# 9 Visit 2025090600253, Detector 53: Found 1 candidate matches.
# 10 Visit 2025090600270, Detector 53: Found 1 candidate matches.
# 11 Visit 2025090600285, Detector 53: Found 1 candidate matches.
# 12 Visit 2025090600277, Detector 60: Found 1 candidate matches.
# 14 Visit 2025090600278, Detector 61: Found 1 candidate matches.
# 15 Visit 2025090600262, Detector 86: Found 1 candidate matches.
# 16 Visit 2025081000328, Detector 90: Found 1 candidate matches.
# 17 Visit 2025081000329, Detector 90: Found 1 candidate matches.
# 18 Visit 2025081000330, Detector 90: Found 1 candidate matches.
# 19 Visit 2025081000331, Detector 90: Found 1 candidate matches.
# 20 Visit 2025081000332, Detector 90: Found 1 candidate matches.
# 21 Visit 2025081000333, Detector 90: Found 1 candidate matches.
# 22 Visit 2025081300332, Detector 90: Found 1 candidate matches.
# 24 Visit 2025090600258, Detector 90: Found 1 candidate matches.
# 25 Visit 2025090600264, Detector 90: Found 1 candidate matches.
# 26 Visit 2025090600269, Detector 90: Found 1 candidate matches.
# 27 Visit 2025090600279, Detector 90: Found 1 candidate matches.
# 29 Visit 2025082600441, Detector 91: Found 1 candidate matches.
# 30 Visit 2025082600443, Detector 91: Found 1 candidate matches.
# 31 Visit 2025082600444, Detector 91: Found 1 candidate matches.
# 32 Visit 2025082600446, Detector 91: Found 1 candidate matches.
# 33 Visit 2025090600263, Detector 91: Found 1 candidate matches.
# 34 Visit 2025090600272, Detector 91: Found 1 candidate matches.
# 35 Visit 2025090600279, Detector 91: Found 1 candidate matches.
# 36 Visit 2025090600284, Detector 91: Found 1 candidate matches.
# 38 Visit 2025071100810, Detector 92: Found 1 candidate matches.
# 43 Visit 2025071200713, Detector 92: Found 1 candidate matches.
# 44 Visit 2025071200714, Detector 92: Found 1 candidate matches.
# 45 Visit 2025071200735, Detector 92: Found 1 candidate matches.
# 46 Visit 2025071200736, Detector 92: Found 1 candidate matches.
# 47 Visit 2025071200737, Detector 92: Found 1 candidate matches.
# 48 Visit 2025071200738, Detector 92: Found 1 candidate matches.
# 49 Visit 2025071200739, Detector 92: Found 1 candidate matches.
# 51 Visit 2025081300310, Detector 92: Found 1 candidate matches.
# 52 Visit 2025081300334, Detector 92: Found 1 candidate matches.
# 53 Visit 2025081300336, Detector 92: Found 1 candidate matches.
# 54 Visit 2025090600265, Detector 92: Found 1 candidate matches.
# 55 Visit 2025090600257, Detector 93: Found 1 candidate matches.
# 56 Visit 2025090600267, Detector 93: Found 1 candidate matches.
# 57 Visit 2025090600273, Detector 93: Found 1 candidate matches.
# 58 Visit 2025081300333, Detector 94: Found 1 candidate matches.
# 59 Visit 2025090600261, Detector 94: Found 1 candidate matches.
# 60 Visit 2025090600268, Detector 94: Found 1 candidate matches.
# 61 Visit 2025090600271, Detector 94: Found 1 candidate matches.
# 62 Visit 2025090600276, Detector 94: Found 1 candidate matches.
# 63 Visit 2025071700593, Detector 95: Found 1 candidate matches.
# 64 Visit 2025071700594, Detector 95: Found 1 candidate matches.
# 65 Visit 2025071700595, Detector 95: Found 1 candidate matches.
# 66 Visit 2025071700602, Detector 95: Found 1 candidate matches.
# 67 Visit 2025071700603, Detector 95: Found 1 candidate matches.
# 68 Visit 2025071700604, Detector 95: Found 1 candidate matches.
# 69 Visit 2025071700605, Detector 95: Found 1 candidate matches.
# 70 Visit 2025071700606, Detector 95: Found 1 candidate matches.
# 71 Visit 2025071700607, Detector 95: Found 1 candidate matches.
# 72 Visit 2025071900574, Detector 95: Found 1 candidate matches.
# 73 Visit 2025071900575, Detector 95: Found 1 candidate matches.
# 74 Visit 2025071900576, Detector 95: Found 1 candidate matches.
# 75 Visit 2025071900577, Detector 95: Found 1 candidate matches.
# 76 Visit 2025071900578, Detector 95: Found 1 candidate matches.
# 77 Visit 2025071900579, Detector 95: Found 1 candidate matches.
# 78 Visit 2025071900580, Detector 95: Found 1 candidate matches.
# 79 Visit 2025071900586, Detector 95: Found 1 candidate matches.
# 80 Visit 2025071900587, Detector 95: Found 1 candidate matches.
# 81 Visit 2025071900588, Detector 95: Found 1 candidate matches.
# 82 Visit 2025071900589, Detector 95: Found 1 candidate matches.
# 83 Visit 2025071900590, Detector 95: Found 1 candidate matches.
# 84 Visit 2025072100524, Detector 95: Found 1 candidate matches.
# 85 Visit 2025072100525, Detector 95: Found 1 candidate matches.
# 86 Visit 2025072100526, Detector 95: Found 1 candidate matches.
# 87 Visit 2025072100527, Detector 95: Found 1 candidate matches.
# 88 Visit 2025072100528, Detector 95: Found 1 candidate matches.
# 89 Visit 2025072100529, Detector 95: Found 1 candidate matches.
# 90 Visit 2025072100530, Detector 95: Found 1 candidate matches.
# 91 Visit 2025072100531, Detector 95: Found 1 candidate matches.
# 92 Visit 2025072100532, Detector 95: Found 1 candidate matches.
# 93 Visit 2025072100533, Detector 95: Found 1 candidate matches.
# 94 Visit 2025072100534, Detector 95: Found 1 candidate matches.
# 95 Visit 2025072100535, Detector 95: Found 1 candidate matches.
# 96 Visit 2025072200465, Detector 95: Found 1 candidate matches.
# 97 Visit 2025072200466, Detector 95: Found 1 candidate matches.
# 98 Visit 2025072200467, Detector 95: Found 1 candidate matches.
# 99 Visit 2025072200468, Detector 95: Found 1 candidate matches.
# 100 Visit 2025072200469, Detector 95: Found 1 candidate matches.
# 101 Visit 2025072200470, Detector 95: Found 1 candidate matches.
# 102 Visit 2025072200474, Detector 95: Found 1 candidate matches.
# 103 Visit 2025072200478, Detector 95: Found 1 candidate matches.
# 104 Visit 2025072200479, Detector 95: Found 1 candidate matches.
# 105 Visit 2025072200480, Detector 95: Found 1 candidate matches.
# 106 Visit 2025072200481, Detector 95: Found 1 candidate matches.
# 107 Visit 2025072200482, Detector 95: Found 1 candidate matches.
# 108 Visit 2025072300437, Detector 95: Found 1 candidate matches.
# 109 Visit 2025072300438, Detector 95: Found 1 candidate matches.
# 110 Visit 2025072300445, Detector 95: Found 1 candidate matches.
# 111 Visit 2025072300446, Detector 95: Found 1 candidate matches.
# 112 Visit 2025072300447, Detector 95: Found 1 candidate matches.
# 113 Visit 2025072300448, Detector 95: Found 1 candidate matches.
# 114 Visit 2025072300449, Detector 95: Found 1 candidate matches.
# 115 Visit 2025072300450, Detector 95: Found 1 candidate matches.
# 116 Visit 2025072800366, Detector 95: Found 1 candidate matches.
# 117 Visit 2025072800368, Detector 95: Found 1 candidate matches.
# 118 Visit 2025072800369, Detector 95: Found 1 candidate matches.
# 119 Visit 2025072800370, Detector 95: Found 1 candidate matches.
# 120 Visit 2025072800371, Detector 95: Found 1 candidate matches.
# 121 Visit 2025072800396, Detector 95: Found 1 candidate matches.
# 122 Visit 2025072800397, Detector 95: Found 1 candidate matches.
# 123 Visit 2025072800398, Detector 95: Found 1 candidate matches.
# 124 Visit 2025072800399, Detector 95: Found 1 candidate matches.
# 125 Visit 2025072800400, Detector 95: Found 1 candidate matches.
# 126 Visit 2025072800401, Detector 95: Found 1 candidate matches.
# 128 Visit 2025081300307, Detector 95: Found 1 candidate matches.
# 130 Visit 2025081300333, Detector 95: Found 1 candidate matches.
# 132 Visit 2025081300337, Detector 95: Found 1 candidate matches.
# 133 Visit 2025082600425, Detector 95: Found 1 candidate matches.
# 134 Visit 2025082600430, Detector 95: Found 1 candidate matches.
# 135 Visit 2025090600275, Detector 98: Found 1 candidate matches.
# 136 Visit 2025090600281, Detector 98: Found 1 candidate matches.
# 137 Visit 2025090600283, Detector 98: Found 1 candidate matches.
# 139 Visit 2025071100810, Detector 99: Found 1 candidate matches.
# 148 Visit 2025081300308, Detector 99: Found 1 candidate matches.
# 149 Visit 2025090600282, Detector 99: Found 1 candidate matches.
# 152 Visit 2025081300337, Detector 102: Found 1 candidate matches.
# 153 Visit 2025082600426, Detector 102: Found 1 candidate matches.
# 154 Visit 2025082600427, Detector 102: Found 1 candidate matches.
# 155 Visit 2025082600428, Detector 102: Found 1 candidate matches.
# 156 Visit 2025082600429, Detector 102: Found 1 candidate matches.
#
# Total combined catalog contains 132 candidate sources.

# %% [markdown]
# Let's look at the result:

# %%
best_df
# Out:
#       coord_ra  coord_dec     parentSourceId            x            y  \
# 0    53.137020 -27.863444                  0  3120.952901   898.311685
# 1    53.137037 -27.863427                  0  3522.051588  3813.636201
# 2    53.137036 -27.863449  25187646755569994  3339.724660  1490.556760
# 3    53.137038 -27.863425                  0  1189.991493  2534.287422
# 4    53.137025 -27.863437                  0  1057.200159  2894.721267
# ..         ...        ...                ...          ...          ...
# 127  53.137030 -27.863437  25082104534008611  3994.252396  1598.965476
# 128  53.137014 -27.863434  25139291087700181  2406.591463   512.423327
# 129  53.137020 -27.863438                  0  2275.111407  2894.639701
# 130  53.137020 -27.863446  25139291356136334  2111.403677  2057.107811
# 131  53.137016 -27.863438  25139291490353729  1727.637731  1498.537950
#
#          xErr      yErr         ra        dec         raErr  ...  \
# 0    0.009363  0.008345  53.137020 -27.863444  4.472117e-07  ...
# 1    0.010376  0.010276  53.137037 -27.863427  5.073094e-07  ...
# 2    0.008722  0.009695  53.137036 -27.863449  4.483496e-07  ...
# 3    0.007879  0.006267  53.137038 -27.863425  3.794090e-07  ...
# 4    0.004048  0.004155  53.137025 -27.863437  1.992035e-07  ...
# ..        ...       ...        ...        ...           ...  ...
# 127  0.002811  0.002851  53.137030 -27.863437  1.393186e-07  ...
# 128  0.005698  0.005295  53.137014 -27.863434  2.644275e-07  ...
# 129  0.005020  0.005116  53.137020 -27.863438  2.505856e-07  ...
# 130  0.005123  0.006071  53.137020 -27.863446  2.906888e-07  ...
# 131  0.005785  0.006433  53.137016 -27.863438  3.112031e-07  ...
#
#      hsmShapeRegauss_flag_no_pixels  hsmShapeRegauss_flag_not_contained  \
# 0                             False                               False
# 1                             False                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
# ..                              ...                                 ...
# 127                           False                               False
# 128                           False                               False
# 129                           False                               False
# 130                           False                               False
# 131                           False                               False
#
#      hsmShapeRegauss_flag_parent_source  sky_source          visit  detector  \
# 0                                 False       False  2025090600260        44
# 1                                 False       False  2025090600252        49
# 2                                 False       False  2025090600256        51
# 3                                 False       False  2025090600266        51
# 4                                 False       False  2025082600442        52
# ..                                  ...         ...            ...       ...
# 127                               False       False  2025081300337        95
# 128                               False       False  2025082600426       102
# 129                               False       False  2025082600427       102
# 130                               False       False  2025082600428       102
# 131                               False       False  2025082600429       102
#
#      band  physical_filter           sourceId  separation_c26202
# 0       z             z_20  25187647288770763           0.584583
# 1       z             z_20  25187646217650971           0.653691
# 2       z             z_20  25187646755570722           0.625556
# 3       z             z_20  25187648097747592           0.662223
# 4       i             i_39  25139293208970777           0.607883
# ..    ...              ...                ...                ...
# 127     z             z_20  25082104534010052           0.620700
# 128     g              g_6  25139291087701777           0.577109
# 129     g              g_6  25139291221918973           0.590262
# 130     g              g_6  25139291356137586           0.581639
# 131     g              g_6  25139291490354913           0.579846
#
# [132 rows x 157 columns]

# %% [markdown]
# #### 3.2.4 Save `best_df` as a CSV file

# %% [markdown]
# Let's save `best_df` as a CSV file that we can download and examine with TOPCAT:
#
# ***(Rename this file to something else???)***

# %%
#best_df.to_csv('LSSTComCam_C26202_fields.csv', index=False)

# %% [markdown]
# Add magCalib and magCalibErr columns:

# %%
# Flux in nano-Janskys to AB magnitudes:
best_df['magCalib'] = -2.5*np.log10(best_df['calibFlux']) + 31.4

# Flux error in nano-Janskys to AB magnitude error:
# Factor of 2.5/math.log(10) is explained here:  https://astronomy.stackexchange.com/questions/38371/how-can-i-calculate-the-uncertainties-in-magnitude-like-the-cds-does
best_df['magCalibErr'] = 2.5/math.log(10)*best_df['calibFluxErr']/best_df['calibFlux']

# %% [markdown]
# Display `visit`, `detector`, `band`, `calibFlux`, `calibFluxErr`, `magCalib`, `magCalibErr`, and `separation_c26202` from best_df, sorted by `visit` and `band`:

# %%
# Set pandas to show all rows...
pd.set_option("display.max_rows", None)

# %%
best_df[['visit', 'detector', 'band', 'calibFlux', 'calibFluxErr', 'magCalib', 'magCalibErr', 'separation_c26202']].sort_values(['visit', 'band'])
# Out:
#              visit  detector band     calibFlux  calibFluxErr   magCalib  \
# 32   2025071100810        99    g  7.644474e+05   1939.002634  16.691631
# 124  2025071100810        99    g  7.644474e+05   1939.002634  16.691631
# 33   2025071200713        92    r  1.032365e+06   1539.219313  16.365417
# 34   2025071200714        92    r  1.032831e+06   1518.033854  16.364927
# 35   2025071200735        92    z  1.156340e+06   2264.239020  16.242287
# 36   2025071200736        92    z  1.155112e+06   2274.770236  16.243440
# 37   2025071200737        92    z  1.155694e+06   2271.487041  16.242893
# 38   2025071200738        92    z  1.150198e+06   2289.503588  16.248069
# 39   2025071200739        92    z  1.151946e+06   2231.485982  16.246420
# 52   2025071700593        95    g  7.565079e+05    949.659169  16.702966
# 53   2025071700594        95    g  7.579397e+05    948.282714  16.700913
# 54   2025071700595        95    g  7.588910e+05    941.268817  16.699552
# 55   2025071700602        95    i  1.156308e+06   1295.815078  16.242317
# 56   2025071700603        95    i  1.160268e+06   1293.024219  16.238604
# 57   2025071700604        95    i  1.157565e+06   1293.314710  16.241136
# 58   2025071700605        95    i  1.156295e+06   1292.262905  16.242328
# 59   2025071700606        95    i  1.158277e+06   1283.120543  16.240469
# 60   2025071700607        95    i  1.159617e+06   1285.272653  16.239213
# 61   2025071900574        95    i  1.156742e+06   1276.982441  16.241909
# 62   2025071900575        95    g  7.542330e+05    749.345850  16.706236
# 63   2025071900576        95    g  7.575269e+05    755.485268  16.701505
# 64   2025071900577        95    g  7.572520e+05    752.209645  16.701899
# 65   2025071900578        95    g  7.590994e+05    746.108297  16.699253
# 66   2025071900579        95    g  7.587468e+05    750.582458  16.699758
# 67   2025071900580        95    g  7.551113e+05    756.863273  16.704973
# 68   2025071900586        95    i  1.158549e+06   1265.141172  16.240214
# 69   2025071900587        95    i  1.156498e+06   1269.852132  16.242138
# 70   2025071900588        95    i  1.157044e+06   1266.658956  16.241625
# 71   2025071900589        95    i  1.157949e+06   1268.282562  16.240776
# 72   2025071900590        95    i  1.158382e+06   1263.011981  16.240370
# 73   2025072100524        95    g  7.560766e+05    762.223536  16.703585
# 74   2025072100525        95    g  7.546204e+05    769.220981  16.705679
# 75   2025072100526        95    g  7.549869e+05    764.655685  16.705151
# 76   2025072100527        95    g  7.547456e+05    750.462111  16.705498
# 77   2025072100528        95    g  7.562134e+05    746.569921  16.703389
# 78   2025072100529        95    g  7.551109e+05    749.675366  16.704973
# 79   2025072100530        95    i  1.158624e+06   1205.223593  16.240144
# 80   2025072100531        95    i  1.157634e+06   1211.554655  16.241072
# 81   2025072100532        95    i  1.159836e+06   1229.167434  16.239008
# 82   2025072100533        95    i  1.157542e+06   1218.422345  16.241158
# 83   2025072100534        95    i  1.154046e+06   1209.389918  16.244442
# 84   2025072100535        95    i  1.154298e+06   1204.597523  16.244205
# 85   2025072200465        95    r  1.069517e+06   2107.760933  16.327031
# 86   2025072200466        95    r  9.833261e+05   2364.465290  16.418256
# 87   2025072200467        95    r  1.023666e+06   2474.657997  16.374604
# 88   2025072200468        95    r  1.145566e+06   2126.751350  16.252450
# 89   2025072200469        95    r  9.376672e+05   2279.802404  16.469878
# 90   2025072200470        95    r  1.071707e+06   1900.843586  16.324810
# 91   2025072200474        95    z  1.170608e+06   3610.989677  16.228971
# 92   2025072200478        95    z  1.151475e+06   2875.928335  16.246864
# 93   2025072200479        95    z  1.150811e+06   3613.561510  16.247490
# 94   2025072200480        95    z  1.170827e+06   3449.676772  16.228768
# 95   2025072200481        95    z  1.113717e+06   3297.759393  16.283062
# 96   2025072200482        95    z  1.119619e+06   2893.398358  16.277325
# 97   2025072300437        95    g  7.753577e+05   1682.433107  16.676245
# 98   2025072300438        95    g  7.615446e+05   1600.991721  16.695762
# 99   2025072300445        95    i  1.162380e+06   1854.170972  16.236630
# 100  2025072300446        95    i  1.160362e+06   1764.345477  16.238516
# 101  2025072300447        95    i  1.147696e+06   1796.850823  16.250433
# 102  2025072300448        95    i  1.156506e+06   1904.041845  16.242130
# 103  2025072300449        95    i  1.168265e+06   1824.987848  16.231146
# 104  2025072300450        95    i  1.153977e+06   1774.896903  16.244507
# 105  2025072800366        95    z  1.153322e+06   1667.689000  16.245124
# 106  2025072800368        95    z  1.148177e+06   1724.894911  16.249978
# 107  2025072800369        95    z  1.153037e+06   1708.946686  16.245392
# 108  2025072800370        95    z  1.153452e+06   1692.808053  16.245001
# 109  2025072800371        95    z  1.152482e+06   1682.986302  16.245914
# 110  2025072800396        95    r  1.036207e+06    857.659733  16.361383
# 111  2025072800397        95    r  1.035223e+06    858.588428  16.362415
# 112  2025072800398        95    r  1.036248e+06    859.620647  16.361341
# 113  2025072800399        95    r  1.033286e+06    854.359010  16.364449
# 114  2025072800400        95    r  1.036798e+06    856.183173  16.360765
# 115  2025072800401        95    r  1.033708e+06    849.913870  16.364006
# 13   2025081000328        90    i  1.152405e+06   1783.028359  16.245987
# 14   2025081000329        90    i  1.153699e+06   1786.075942  16.244768
# 15   2025081000330        90    i  1.153172e+06   1775.876130  16.245264
# 16   2025081000331        90    i  1.155191e+06   1772.165167  16.243365
# 17   2025081000332        90    i  1.155182e+06   1753.669984  16.243374
# 18   2025081000333        90    i  1.152468e+06   1746.852013  16.245928
# 116  2025081300307        95    r  1.038352e+06   1105.087072  16.359139
# 125  2025081300308        99    r  1.042419e+06   1103.737362  16.354895
# 40   2025081300310        92    r  1.042210e+06   1103.499289  16.355112
# 19   2025081300332        90    z  1.159058e+06   1765.873850  16.239737
# 47   2025081300333        94    z  1.161923e+06   1791.662489  16.237057
# 117  2025081300333        94    z  1.161923e+06   1791.662489  16.237057
# 41   2025081300334        92    z  1.158354e+06   1790.624481  16.240397
# 42   2025081300336        92    z  1.165499e+06   1772.136764  16.233720
# 118  2025081300337        95    z  1.159608e+06   1769.951058  16.239222
# 127  2025081300337        95    z  1.159608e+06   1769.951058  16.239222
# 119  2025082600425        95    g  7.613605e+05    674.838547  16.696024
# 128  2025082600426       102    g  7.586981e+05    678.335972  16.699827
# 129  2025082600427       102    g  7.614347e+05    680.865005  16.695918
# 130  2025082600428       102    g  7.587972e+05    687.099135  16.699686
# 131  2025082600429       102    g  7.601675e+05    709.483598  16.697727
# 120  2025082600430        92    g  7.620698e+05    679.443122  16.695013
# 24   2025082600441        91    i  1.154862e+06   1049.490181  16.243675
# 4    2025082600442        52    i  1.152023e+06   1043.310444  16.246347
# 25   2025082600443        91    i  1.157297e+06   1049.478513  16.241388
# 26   2025082600444        91    i  1.158687e+06   1047.443935  16.240085
# 5    2025082600445        52    i  1.155365e+06   1044.059507  16.243202
# 27   2025082600446        91    i  1.156079e+06   1040.712105  16.242531
# 1    2025090600252        49    z  1.163526e+06   2383.817302  16.235560
# 7    2025090600253        53    z  1.154943e+06   2572.031873  16.243598
# 6    2025090600254        52    z  1.151317e+06   2352.711099  16.247012
# 2    2025090600256        51    z  1.150159e+06   2427.765812  16.248106
# 44   2025090600257        93    z  1.156646e+06   2430.349856  16.241999
# 20   2025090600258        90    z  1.161170e+06   2392.600774  16.237760
# 0    2025090600260        44    z  1.153523e+06   2448.553907  16.244934
# 48   2025090600261        94    z  1.153687e+06   2584.460398  16.244780
# 12   2025090600262        86    z  1.161678e+06   2416.907393  16.237285
# 28   2025090600263        91    z  1.155816e+06   2407.727485  16.242778
# 21   2025090600264        90    z  1.155083e+06   2336.650453  16.243467
# 43   2025090600265        92    z  1.155536e+06   2332.785742  16.243041
# 3    2025090600266        51    z  1.152998e+06   2270.059010  16.245429
# 45   2025090600267        93    z  1.152775e+06   2336.621253  16.245639
# 49   2025090600268        94    z  1.156010e+06   2366.868620  16.242596
# 22   2025090600269        90    z  1.155111e+06   2333.408305  16.243441
# 8    2025090600270        53    z  1.154913e+06   2250.158845  16.243627
# 50   2025090600271        94    r  1.035117e+06   2017.952153  16.362526
# 29   2025090600272        91    r  1.038118e+06   1937.352952  16.359383
# 46   2025090600273        93    r  1.030723e+06   1893.355211  16.367145
# 121  2025090600275        98    r  1.036689e+06   1888.032714  16.360879
# 51   2025090600276        94    r  1.033825e+06   1876.638826  16.363883
# 10   2025090600277        60    r  1.029930e+06   1906.769581  16.367980
# 11   2025090600278        61    r  1.036849e+06   2057.629164  16.360711
# 23   2025090600279        90    r  1.033509e+06   1973.053990  16.364214
# 30   2025090600279        90    r  1.033509e+06   1973.053990  16.364214
# 122  2025090600281        98    r  1.035368e+06   1866.104668  16.362263
# 126  2025090600282        99    r  1.032867e+06   1897.990081  16.364889
# 123  2025090600283        98    r  1.033986e+06   1879.388080  16.363714
# 31   2025090600284        91    r  1.043653e+06   1845.463742  16.353610
# 9    2025090600285        53    r  1.034467e+06   1828.121152  16.363209
#
#      magCalibErr  separation_c26202
# 32      0.002754           0.637541
# 124     0.002754           0.637541
# 33      0.001619           0.622717
# 34      0.001596           0.613588
# 35      0.002126           0.611381
# 36      0.002138           0.617362
# 37      0.002134           0.595738
# 38      0.002161           0.632586
# 39      0.002103           0.616421
# 52      0.001363           0.572067
# 53      0.001358           0.565996
# 54      0.001347           0.579709
# 55      0.001217           0.621880
# 56      0.001210           0.598846
# 57      0.001213           0.593181
# 58      0.001213           0.601001
# 59      0.001203           0.586427
# 60      0.001203           0.560592
# 61      0.001199           0.614472
# 62      0.001079           0.544364
# 63      0.001083           0.595787
# 64      0.001079           0.514731
# 65      0.001067           0.571380
# 66      0.001074           0.542702
# 67      0.001088           0.554952
# 68      0.001186           0.563337
# 69      0.001192           0.583915
# 70      0.001189           0.604211
# 71      0.001189           0.606724
# 72      0.001184           0.647135
# 73      0.001095           0.515613
# 74      0.001107           0.513820
# 75      0.001100           0.528975
# 76      0.001080           0.535861
# 77      0.001072           0.509526
# 78      0.001078           0.499529
# 79      0.001129           0.624428
# 80      0.001136           0.591732
# 81      0.001151           0.686640
# 82      0.001143           0.567032
# 83      0.001138           0.599628
# 84      0.001133           0.610097
# 85      0.002140           0.590301
# 86      0.002611           0.615369
# 87      0.002625           0.597999
# 88      0.002016           0.624666
# 89      0.002640           0.591232
# 90      0.001926           0.581260
# 91      0.003349           0.608178
# 92      0.002712           0.624470
# 93      0.003409           0.637645
# 94      0.003199           0.631009
# 95      0.003215           0.609874
# 96      0.002806           0.604929
# 97      0.002356           0.597699
# 98      0.002283           0.638215
# 99      0.001732           0.632613
# 100     0.001651           0.634086
# 101     0.001700           0.628001
# 102     0.001788           0.619346
# 103     0.001696           0.605076
# 104     0.001670           0.641453
# 105     0.001570           0.623913
# 106     0.001631           0.597332
# 107     0.001609           0.603671
# 108     0.001593           0.657796
# 109     0.001586           0.607014
# 110     0.000899           0.619836
# 111     0.000900           0.597080
# 112     0.000901           0.614878
# 113     0.000898           0.605832
# 114     0.000897           0.622101
# 115     0.000893           0.611042
# 13      0.001680           0.636756
# 14      0.001681           0.602728
# 15      0.001672           0.633097
# 16      0.001666           0.625179
# 17      0.001648           0.602261
# 18      0.001646           0.643953
# 116     0.001156           0.614113
# 125     0.001150           0.647007
# 40      0.001150           0.618375
# 19      0.001654           0.617661
# 47      0.001674           0.619069
# 117     0.001674           0.619069
# 41      0.001678           0.614949
# 42      0.001651           0.608166
# 118     0.001657           0.620700
# 127     0.001657           0.620700
# 119     0.000962           0.545940
# 128     0.000971           0.577109
# 129     0.000971           0.590262
# 130     0.000983           0.581639
# 131     0.001013           0.579846
# 120     0.000968           0.585260
# 24      0.000987           0.601003
# 4       0.000983           0.607883
# 25      0.000985           0.615050
# 26      0.000981           0.628346
# 5       0.000981           0.600935
# 27      0.000977           0.616093
# 1       0.002224           0.653691
# 7       0.002418           0.599052
# 6       0.002219           0.611629
# 2       0.002292           0.625556
# 44      0.002281           0.598598
# 20      0.002237           0.643137
# 0       0.002305           0.584583
# 48      0.002432           0.568113
# 12      0.002259           0.653609
# 28      0.002262           0.607636
# 21      0.002196           0.674389
# 43      0.002192           0.636022
# 3       0.002138           0.662223
# 45      0.002201           0.627337
# 49      0.002223           0.594511
# 22      0.002193           0.613420
# 8       0.002115           0.600065
# 50      0.002117           0.614176
# 29      0.002026           0.583772
# 46      0.001994           0.558606
# 121     0.001977           0.612976
# 51      0.001971           0.614354
# 10      0.002010           0.640295
# 11      0.002155           0.604995
# 23      0.002073           0.605687
# 30      0.002073           0.605687
# 122     0.001957           0.609243
# 126     0.001995           0.625083
# 123     0.001973           0.596736
# 31      0.001920           0.584921
# 9       0.001919           0.606273

# %%
print("""Number of rows:  %d""" % (len(best_df['visit'])))
# Out:
# Number of rows:  132

# %%
# Reset pandas to its default maximum rows to print to screen
pd.reset_option("display.max_rows")

# %% [markdown]
# ### 3.4 Match pandas dataframe with observed ComCam magnitudes (best_df) with pandas dataframe with the synthetic magnitudes (df_mags)

# %%
# Reset the index to turn the keys into a column
df_mags_reset = df_mags.reset_index()

# Merge the dataframes based on the filter name
combined_df = pd.merge(best_df, df_mags_reset, left_on='band', right_on='index')

combined_df
# Out:
#       coord_ra  coord_dec     parentSourceId            x            y  \
# 0    53.137020 -27.863444                  0  3120.952901   898.311685
# 1    53.137037 -27.863427                  0  3522.051588  3813.636201
# 2    53.137036 -27.863449  25187646755569994  3339.724660  1490.556760
# 3    53.137038 -27.863425                  0  1189.991493  2534.287422
# 4    53.137025 -27.863437                  0  1057.200159  2894.721267
# ..         ...        ...                ...          ...          ...
# 127  53.137030 -27.863437  25082104534008611  3994.252396  1598.965476
# 128  53.137014 -27.863434  25139291087700181  2406.591463   512.423327
# 129  53.137020 -27.863438                  0  2275.111407  2894.639701
# 130  53.137020 -27.863446  25139291356136334  2111.403677  2057.107811
# 131  53.137016 -27.863438  25139291490353729  1727.637731  1498.537950
#
#          xErr      yErr         ra        dec         raErr  ...  detector  \
# 0    0.009363  0.008345  53.137020 -27.863444  4.472117e-07  ...        44
# 1    0.010376  0.010276  53.137037 -27.863427  5.073094e-07  ...        49
# 2    0.008722  0.009695  53.137036 -27.863449  4.483496e-07  ...        51
# 3    0.007879  0.006267  53.137038 -27.863425  3.794090e-07  ...        51
# 4    0.004048  0.004155  53.137025 -27.863437  1.992035e-07  ...        52
# ..        ...       ...        ...        ...           ...  ...       ...
# 127  0.002811  0.002851  53.137030 -27.863437  1.393186e-07  ...        95
# 128  0.005698  0.005295  53.137014 -27.863434  2.644275e-07  ...       102
# 129  0.005020  0.005116  53.137020 -27.863438  2.505856e-07  ...       102
# 130  0.005123  0.006071  53.137020 -27.863446  2.906888e-07  ...       102
# 131  0.005785  0.006433  53.137016 -27.863438  3.112031e-07  ...       102
#
#      band  physical_filter           sourceId  separation_c26202   magCalib  \
# 0       z             z_20  25187647288770763           0.584583  16.244934
# 1       z             z_20  25187646217650971           0.653691  16.235560
# 2       z             z_20  25187646755570722           0.625556  16.248106
# 3       z             z_20  25187648097747592           0.662223  16.245429
# 4       i             i_39  25139293208970777           0.607883  16.246347
# ..    ...              ...                ...                ...        ...
# 127     z             z_20  25082104534010052           0.620700  16.239222
# 128     g              g_6  25139291087701777           0.577109  16.699827
# 129     g              g_6  25139291221918973           0.590262  16.695918
# 130     g              g_6  25139291356137586           0.581639  16.699686
# 131     g              g_6  25139291490354913           0.579846  16.697727
#
#      magCalibErr  index  stiswfcnic_007    mod_008
# 0       0.002305      z       16.243679  16.243690
# 1       0.002224      z       16.243679  16.243690
# 2       0.002292      z       16.243679  16.243690
# 3       0.002138      z       16.243679  16.243690
# 4       0.000983      i       16.260196  16.259542
# ..           ...    ...             ...        ...
# 127     0.001657      z       16.243679  16.243690
# 128     0.000971      g       16.691931  16.692687
# 129     0.000971      g       16.691931  16.692687
# 130     0.000983      g       16.691931  16.692687
# 131     0.001013      g       16.691931  16.692687
#
# [132 rows x 162 columns]

# %%
print(df_mags)
# Out:
#    stiswfcnic_007    mod_008
# u       17.572800  17.586964
# g       16.691931  16.692687
# r       16.362017  16.361654
# i       16.260196  16.259542
# z       16.243679  16.243690
# y       16.238847  16.238887

# %%
# Group by the 'band' column and calculate the median of 'magCalib' for each group
median_values = combined_df.groupby('band')['magCalib'].median().reset_index()
median_values = median_values.rename(columns={'magCalib': 'median_magCalib'})

# Merge the median values back into the combined_df dataframe
combined_df = pd.merge(combined_df, median_values, on='band', how='left')
combined_df
# Out:
#       coord_ra  coord_dec     parentSourceId            x            y  \
# 0    53.137020 -27.863444                  0  3120.952901   898.311685
# 1    53.137037 -27.863427                  0  3522.051588  3813.636201
# 2    53.137036 -27.863449  25187646755569994  3339.724660  1490.556760
# 3    53.137038 -27.863425                  0  1189.991493  2534.287422
# 4    53.137025 -27.863437                  0  1057.200159  2894.721267
# ..         ...        ...                ...          ...          ...
# 127  53.137030 -27.863437  25082104534008611  3994.252396  1598.965476
# 128  53.137014 -27.863434  25139291087700181  2406.591463   512.423327
# 129  53.137020 -27.863438                  0  2275.111407  2894.639701
# 130  53.137020 -27.863446  25139291356136334  2111.403677  2057.107811
# 131  53.137016 -27.863438  25139291490353729  1727.637731  1498.537950
#
#          xErr      yErr         ra        dec         raErr  ...  band  \
# 0    0.009363  0.008345  53.137020 -27.863444  4.472117e-07  ...     z
# 1    0.010376  0.010276  53.137037 -27.863427  5.073094e-07  ...     z
# 2    0.008722  0.009695  53.137036 -27.863449  4.483496e-07  ...     z
# 3    0.007879  0.006267  53.137038 -27.863425  3.794090e-07  ...     z
# 4    0.004048  0.004155  53.137025 -27.863437  1.992035e-07  ...     i
# ..        ...       ...        ...        ...           ...  ...   ...
# 127  0.002811  0.002851  53.137030 -27.863437  1.393186e-07  ...     z
# 128  0.005698  0.005295  53.137014 -27.863434  2.644275e-07  ...     g
# 129  0.005020  0.005116  53.137020 -27.863438  2.505856e-07  ...     g
# 130  0.005123  0.006071  53.137020 -27.863446  2.906888e-07  ...     g
# 131  0.005785  0.006433  53.137016 -27.863438  3.112031e-07  ...     g
#
#      physical_filter           sourceId  separation_c26202   magCalib  \
# 0               z_20  25187647288770763           0.584583  16.244934
# 1               z_20  25187646217650971           0.653691  16.235560
# 2               z_20  25187646755570722           0.625556  16.248106
# 3               z_20  25187648097747592           0.662223  16.245429
# 4               i_39  25139293208970777           0.607883  16.246347
# ..               ...                ...                ...        ...
# 127             z_20  25082104534010052           0.620700  16.239222
# 128              g_6  25139291087701777           0.577109  16.699827
# 129              g_6  25139291221918973           0.590262  16.695918
# 130              g_6  25139291356137586           0.581639  16.699686
# 131              g_6  25139291490354913           0.579846  16.697727
#
#      magCalibErr  index  stiswfcnic_007    mod_008  median_magCalib
# 0       0.002305      z       16.243679  16.243690        16.243454
# 1       0.002224      z       16.243679  16.243690        16.243454
# 2       0.002292      z       16.243679  16.243690        16.243454
# 3       0.002138      z       16.243679  16.243690        16.243454
# 4       0.000983      i       16.260196  16.259542        16.242019
# ..           ...    ...             ...        ...              ...
# 127     0.001657      z       16.243679  16.243690        16.243454
# 128     0.000971      g       16.691931  16.692687        16.699827
# 129     0.000971      g       16.691931  16.692687        16.699827
# 130     0.000983      g       16.691931  16.692687        16.699827
# 131     0.001013      g       16.691931  16.692687        16.699827
#
# [132 rows x 163 columns]

# %%
# Calculate the number of rows for each filter band
row_counts = combined_df.groupby('band').size().reset_index(name='n_total')

# Merge the row counts back into the combined_df dataframe
combined_df = pd.merge(combined_df, row_counts, on='band', how='left')

combined_df
# Out:
#       coord_ra  coord_dec     parentSourceId            x            y  \
# 0    53.137020 -27.863444                  0  3120.952901   898.311685
# 1    53.137037 -27.863427                  0  3522.051588  3813.636201
# 2    53.137036 -27.863449  25187646755569994  3339.724660  1490.556760
# 3    53.137038 -27.863425                  0  1189.991493  2534.287422
# 4    53.137025 -27.863437                  0  1057.200159  2894.721267
# ..         ...        ...                ...          ...          ...
# 127  53.137030 -27.863437  25082104534008611  3994.252396  1598.965476
# 128  53.137014 -27.863434  25139291087700181  2406.591463   512.423327
# 129  53.137020 -27.863438                  0  2275.111407  2894.639701
# 130  53.137020 -27.863446  25139291356136334  2111.403677  2057.107811
# 131  53.137016 -27.863438  25139291490353729  1727.637731  1498.537950
#
#          xErr      yErr         ra        dec         raErr  ...  \
# 0    0.009363  0.008345  53.137020 -27.863444  4.472117e-07  ...
# 1    0.010376  0.010276  53.137037 -27.863427  5.073094e-07  ...
# 2    0.008722  0.009695  53.137036 -27.863449  4.483496e-07  ...
# 3    0.007879  0.006267  53.137038 -27.863425  3.794090e-07  ...
# 4    0.004048  0.004155  53.137025 -27.863437  1.992035e-07  ...
# ..        ...       ...        ...        ...           ...  ...
# 127  0.002811  0.002851  53.137030 -27.863437  1.393186e-07  ...
# 128  0.005698  0.005295  53.137014 -27.863434  2.644275e-07  ...
# 129  0.005020  0.005116  53.137020 -27.863438  2.505856e-07  ...
# 130  0.005123  0.006071  53.137020 -27.863446  2.906888e-07  ...
# 131  0.005785  0.006433  53.137016 -27.863438  3.112031e-07  ...
#
#      physical_filter           sourceId  separation_c26202   magCalib  \
# 0               z_20  25187647288770763           0.584583  16.244934
# 1               z_20  25187646217650971           0.653691  16.235560
# 2               z_20  25187646755570722           0.625556  16.248106
# 3               z_20  25187648097747592           0.662223  16.245429
# 4               i_39  25139293208970777           0.607883  16.246347
# ..               ...                ...                ...        ...
# 127             z_20  25082104534010052           0.620700  16.239222
# 128              g_6  25139291087701777           0.577109  16.699827
# 129              g_6  25139291221918973           0.590262  16.695918
# 130              g_6  25139291356137586           0.581639  16.699686
# 131              g_6  25139291490354913           0.579846  16.697727
#
#      magCalibErr  index  stiswfcnic_007    mod_008  median_magCalib  n_total
# 0       0.002305      z       16.243679  16.243690        16.243454       40
# 1       0.002224      z       16.243679  16.243690        16.243454       40
# 2       0.002292      z       16.243679  16.243690        16.243454       40
# 3       0.002138      z       16.243679  16.243690        16.243454       40
# 4       0.000983      i       16.260196  16.259542        16.242019       36
# ..           ...    ...             ...        ...              ...      ...
# 127     0.001657      z       16.243679  16.243690        16.243454       40
# 128     0.000971      g       16.691931  16.692687        16.699827       25
# 129     0.000971      g       16.691931  16.692687        16.699827       25
# 130     0.000983      g       16.691931  16.692687        16.699827       25
# 131     0.001013      g       16.691931  16.692687        16.699827       25
#
# [132 rows x 164 columns]

# %% [markdown]
# **calculate the median then combine the tables for stis and mod**

# %%
# Calculate the number of rows for each filter band
row_counts = best_df.groupby('band').size().reset_index(name='n_band')

# Merge the row counts back into the combined_df dataframe
combined_df = pd.merge(best_df, row_counts, on='band', how='left')

combined_df
# Out:
#       coord_ra  coord_dec     parentSourceId            x            y  \
# 0    53.137020 -27.863444                  0  3120.952901   898.311685
# 1    53.137037 -27.863427                  0  3522.051588  3813.636201
# 2    53.137036 -27.863449  25187646755569994  3339.724660  1490.556760
# 3    53.137038 -27.863425                  0  1189.991493  2534.287422
# 4    53.137025 -27.863437                  0  1057.200159  2894.721267
# ..         ...        ...                ...          ...          ...
# 127  53.137030 -27.863437  25082104534008611  3994.252396  1598.965476
# 128  53.137014 -27.863434  25139291087700181  2406.591463   512.423327
# 129  53.137020 -27.863438                  0  2275.111407  2894.639701
# 130  53.137020 -27.863446  25139291356136334  2111.403677  2057.107811
# 131  53.137016 -27.863438  25139291490353729  1727.637731  1498.537950
#
#          xErr      yErr         ra        dec         raErr  ...  sky_source  \
# 0    0.009363  0.008345  53.137020 -27.863444  4.472117e-07  ...       False
# 1    0.010376  0.010276  53.137037 -27.863427  5.073094e-07  ...       False
# 2    0.008722  0.009695  53.137036 -27.863449  4.483496e-07  ...       False
# 3    0.007879  0.006267  53.137038 -27.863425  3.794090e-07  ...       False
# 4    0.004048  0.004155  53.137025 -27.863437  1.992035e-07  ...       False
# ..        ...       ...        ...        ...           ...  ...         ...
# 127  0.002811  0.002851  53.137030 -27.863437  1.393186e-07  ...       False
# 128  0.005698  0.005295  53.137014 -27.863434  2.644275e-07  ...       False
# 129  0.005020  0.005116  53.137020 -27.863438  2.505856e-07  ...       False
# 130  0.005123  0.006071  53.137020 -27.863446  2.906888e-07  ...       False
# 131  0.005785  0.006433  53.137016 -27.863438  3.112031e-07  ...       False
#
#              visit  detector  band  physical_filter           sourceId  \
# 0    2025090600260        44     z             z_20  25187647288770763
# 1    2025090600252        49     z             z_20  25187646217650971
# 2    2025090600256        51     z             z_20  25187646755570722
# 3    2025090600266        51     z             z_20  25187648097747592
# 4    2025082600442        52     i             i_39  25139293208970777
# ..             ...       ...   ...              ...                ...
# 127  2025081300337        95     z             z_20  25082104534010052
# 128  2025082600426       102     g              g_6  25139291087701777
# 129  2025082600427       102     g              g_6  25139291221918973
# 130  2025082600428       102     g              g_6  25139291356137586
# 131  2025082600429       102     g              g_6  25139291490354913
#
#      separation_c26202   magCalib  magCalibErr  n_band
# 0             0.584583  16.244934     0.002305      40
# 1             0.653691  16.235560     0.002224      40
# 2             0.625556  16.248106     0.002292      40
# 3             0.662223  16.245429     0.002138      40
# 4             0.607883  16.246347     0.000983      36
# ..                 ...        ...          ...     ...
# 127           0.620700  16.239222     0.001657      40
# 128           0.577109  16.699827     0.000971      25
# 129           0.590262  16.695918     0.000971      25
# 130           0.581639  16.699686     0.000983      25
# 131           0.579846  16.697727     0.001013      25
#
# [132 rows x 160 columns]

# %%
# Group by the 'n_band' column and calculate the counts of 'band' for each group
count_df = best_df.groupby('band')['magCalib'].count().reset_index()

# Rename the columns for clarity
count_df = count_df.rename(columns={'magCalib': 'n_band'})

count_df
# Out:
#   band  n_band
# 0    g      25
# 1    i      36
# 2    r      31
# 3    z      40

# %%
# Group by the 'band' column and calculate the median of 'magCalib' for each group
median_df = best_df.groupby('band')['magCalib'].median().reset_index()

# Rename the columns for clarity
median_df = median_df.rename(columns={'magCalib': 'median_magCalib'})

median_df
# Out:
#   band  median_magCalib
# 0    g        16.699827
# 1    i        16.242019
# 2    r        16.362526
# 3    z        16.243454

# %%
# Merge the dataframes based on the filter name
combined_df = pd.merge(count_df, median_df, left_on='band', right_on='band')

combined_df
# Out:
#   band  n_band  median_magCalib
# 0    g      25        16.699827
# 1    i      36        16.242019
# 2    r      31        16.362526
# 3    z      40        16.243454

# %%
# Reset the index to turn the keys into a column
df_mags_reset = df_mags.reset_index()

# Merge the dataframes based on the filter name
combined_df = pd.merge(combined_df, df_mags_reset, left_on='band', right_on='index')

combined_df
# Out:
#   band  n_band  median_magCalib index  stiswfcnic_007    mod_008
# 0    g      25        16.699827     g       16.691931  16.692687
# 1    i      36        16.242019     i       16.260196  16.259542
# 2    r      31        16.362526     r       16.362017  16.361654
# 3    z      40        16.243454     z       16.243679  16.243690

# %%
# Calculate the differences and add the new columns
combined_df['offset_stis'] = combined_df['median_magCalib'] - combined_df['stiswfcnic_007']
combined_df['offset_mod'] = combined_df['median_magCalib'] - combined_df['mod_008']

combined_df
# Out:
#   band  n_band  median_magCalib index  stiswfcnic_007    mod_008  offset_stis  \
# 0    g      25        16.699827     g       16.691931  16.692687     0.007896
# 1    i      36        16.242019     i       16.260196  16.259542    -0.018176
# 2    r      31        16.362526     r       16.362017  16.361654     0.000509
# 3    z      40        16.243454     z       16.243679  16.243690    -0.000224
#
#    offset_mod
# 0    0.007140
# 1   -0.017523
# 2    0.000872
# 3   -0.000235

# %%
print(combined_df)
# Out:
#   band  n_band  median_magCalib index  stiswfcnic_007    mod_008  offset_stis  \
# 0    g      25        16.699827     g       16.691931  16.692687     0.007896
# 1    i      36        16.242019     i       16.260196  16.259542    -0.018176
# 2    r      31        16.362526     r       16.362017  16.361654     0.000509
# 3    z      40        16.243454     z       16.243679  16.243690    -0.000224
#
#    offset_mod
# 0    0.007140
# 1   -0.017523
# 2    0.000872
# 3   -0.000235

# %%
# Define the desired order of 'band'
order = ['u', 'g', 'r', 'i', 'z', 'y']

# Remove the 'index' column
combined_df = combined_df.drop(columns=['index'])

# Reorder the dataframe based on the 'band' column
combined_df['band'] = pd.Categorical(combined_df['band'], categories=order, ordered=True)
combined_df = combined_df.sort_values('band').reset_index(drop=True)

combined_df
# Out:
#   band  n_band  median_magCalib  stiswfcnic_007    mod_008  offset_stis  \
# 0    g      25        16.699827       16.691931  16.692687     0.007896
# 1    r      31        16.362526       16.362017  16.361654     0.000509
# 2    i      36        16.242019       16.260196  16.259542    -0.018176
# 3    z      40        16.243454       16.243679  16.243690    -0.000224
#
#    offset_mod
# 0    0.007140
# 1    0.000872
# 2   -0.017523
# 3   -0.000235

# %%
raise StopExecution

# %% [markdown]
# ## 5. Sandbox

# %% [markdown]
# the code below is to loop over each of the calspec stars - NOT TESTED YET

# %% [raw]
# import pandas as pd
# from astropy.coordinates import SkyCoord
# import astropy.units as u
#
# # --- Step 1: Load CALSPEC reference stars ---
# calspec_df = pd.read_csv("mag_CalSpec.csv")
#
# # Build dictionary of reference coordinates keyed by Star_Name
# calspec_coords = {
#     row["Star_Name"]: SkyCoord(ra=row["raDeg"]*u.degree, dec=row["decDeg"]*u.degree)
#     for _, row in calspec_df.iterrows()
# }
#
# # --- Step 2: Loop over visits/detectors ---
# matches = {star: [] for star in calspec_coords.keys()}  # dict of lists
#
# for i, ref in enumerate(datasetRefs):
#     dataId = {'visit': ref.dataId['visit'], 'detector': ref.dataId['detector']}
#     src = butler.get('source2', dataId=dataId).to_pandas()
#
#     # Apply "good measurement" mask
#     mask = (~src.pixelFlags_bad) & (~src.pixelFlags_saturated) & \
#            (~src.extendedness_flag) & (src.detect_isPrimary)
#     src_cleaned = src[mask]
#
#     # Build SkyCoord for this detector’s sources
#     df_coords = SkyCoord(ra=src_cleaned['ra'].values*u.degree,
#                          dec=src_cleaned['dec'].values*u.degree)
#
#     # --- Step 3: Check against each CALSPEC star ---
#     for star, ref_coord in calspec_coords.items():
#         separations = ref_coord.separation(df_coords)
#         mask_sep = separations < 3.0*u.arcsec
#
#         if mask_sep.any():
#             nearby = src_cleaned[mask_sep].copy()
#             nearby['separation_arcsec'] = separations[mask_sep].arcsec
#             nearby['visit'] = ref.dataId['visit']
#             nearby['detector'] = ref.dataId['detector']
#
#             # Keep only the closest match for this star in this visit/detector
#             best = nearby.sort_values('separation_arcsec').iloc[[0]]
#             matches[star].append(best)
#
#     print(f"{i}: Visit {ref.dataId['visit']}, Detector {ref.dataId['detector']} processed.")
#
# # --- Step 4: Concatenate results per star ---
# matches_df = {
#     star: pd.concat(lst, ignore_index=True) if lst else pd.DataFrame()
#     for star, lst in matches.items()
# }
#
# # Example: look at matches for C26202
# print(matches_df["C26202"])
